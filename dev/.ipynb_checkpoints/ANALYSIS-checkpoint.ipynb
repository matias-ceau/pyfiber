# %%
# %cd C:\Users\mceau\Documents\fiberphotopy\fiberphotopy\
# Out:
# C:\Users\mceau\Documents\fiberphotopy\fiberphotopy

# %%
import pandas as pd
import fp_utils, behavioral_data, analysis, fiber_data
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import importlib
import yaml
import time
def rel():
    for module in [fp_utils, behavioral_data, analysis, fiber_data]:
        importlib.reload(module)
rel()

import seaborn as sns

# %% [markdown]
# # QUESTIONS:
# + np1 or np1and2
# + avg for all sessions
# + include all sessions ?
# + what to do about ND,NCI, etc
# + is NCI BSL == SA
# + what to do if no D2
#
# # TODO:
# Have a way to :
# - [X] get ID
# - [ ]
#
# ## Make df with (first per session):
# ### Behavioral data:
# - [ ] total ND1 nosepokes (get then median, etc)
# - [ ] 1 min ND1 nosepokes
# - [ ] latencies to first ND1 np
# - [ ] injections in D1
# - [ ] latency to first D2 np
# - [ ] injections in D2
# - [ ] latency to first D1 np
#
# ### Fiber data:
# - [ ] D1/ND1 -- dF/Z -- avg, AUC -- (1,3,5)
# - [ ] -D1    -- dF/Z -- avg, AUC -- (1,3,5)
# - [ ] D amplitude  -- frequency
# - [ ] ND amplitude -- frequency
# ________________________________________________________________________________________________________________________________________________________________________________
# # DETAILS
#
# **Correlation between normalized D1-ND1 DS switch Z-score/ Df/f and total ND1 nosepokes**
# + 1s, 3s, 5s
# total ND1 ======= ok
# ND1_switch ====== ok
#
# **Correlation between normalized D1-ND1 DS switch Z-score/ Df/f and 1 min ND1 nosepokes**
# + 1s, 3s, 5s
# 1min ND1 NP ===== ok
#
# **Correlation between normalized D1-ND1 DS switch Z-score/ Df/f and latency to first ND nosepoke**
# + 1s, 3s, 5s
# latency to first ND ==== ok with user output abs(timestamps('switch_1')[0] - ND_1[0][0])
#
# **Correlation between normalized D1-ND1 DS switch Z-score/ Df/f and inj in previous D period- controlling that the recruitment does not depend on how much cocaine is in the system**
# + 1s, 3s, 5s
# injection during previous D period ===== timestamps('inj1','D_1')
#
# **Split rats into high/low based on ND1 median split**
# + Peak amplitude/frequency differences D / ND
# ND1 median split ======== len('np1','ND_1')/median avg by session ?
#
# **Correlation between normalized -D1 DS switch Z-score/ Df/f and latency to first D nosepoke**
# + 1s, 3s, 5s
# -DS switch ============= start of first D?
# latency to first ========== shoudl be easy
#
# **Correlation between normalized -D1 DS switch Z-score/ Df/f and latency to first injection**
# + 1s, 3s, 5s
#
# **Correlation between normalized -D1 DS switch Z-score/ Df/f and number of injections in D1**
# + 1s, 3s, 5s
# === number of injections in D1
#
# **Correlation between normalized -D1 DS switch Z-score/ Df/f and latency to first D2 nosepoke**
# + 1s, 3s, 5s
# ===== latency to first D2 nosepoke (might be some np.nan)
#
# **Correlation between normalized -D1 DS switch Z-score/ Df/f and latency to first injection D2**
# + 1s, 3s, 5s
# ===== latency to first D2 injection (might be some np.nan)
#
# **Correlation between normalized -D1 DS switch Z-score/ Df/f and number of injections in D1**
# + 1s, 3s, 5s

# %%
rel()

# %%
rel()
sess = analysis.MultiSession('../../DATA/FIBER_SAMPLE/')
# Out:
# folder ../../DATA/FIBER_SAMPLE/
# Folder is indeed a string
# rats ['AD21R_rat_2_SA_j42', 'AK20R_rat_3_SA_j17', 'AL21R_rat_3_NCIBSL_j37', 'AS21R_rat_10_SA1_j22', 'AS21R_rat_11_SA5_j33', 'AS21R_rat_12_SA4', 'AS21R_rat_5_SA6_j37', 'AS21R_rat_8_SA1', 'AS21R_rat_8_SA3_j27']
# 10:04:40 ---
# Importing folder AD21R_rat_2_SA_j42...
# 10:04:40 --- IMPORTING ../../DATA/FIBER_SAMPLE//AD21R_rat_2_SA_j42/bsa11082021c20_01.dat...
# 10:04:40 --- Detecting hled_on...                      ['conditional', [1, 1], ['_P', 1]])
# 10:04:40 --- Detecting hled_off...                     ['conditional', [1, 1], ['_P', 0]])
# 10:04:40 --- Detecting led1_on...                      ['conditional', [1, 2], ['_P', 1]])
# 10:04:40 --- Detecting led1_off...                     ['conditional', [1, 2], ['_P', 0]])
# 10:04:40 --- Detecting led2_on...                      ['conditional', [1, 3], ['_P', 1]])
# 10:04:40 --- Detecting led2_off...                     ['conditional', [1, 3], ['_P', 0]])
# 10:04:40 --- Detecting np1...                          ['conditional', [3, 1], ['_V', 1]])
# 10:04:40 --- Detecting np2...                          ['conditional', [3, 2], ['_V', 1]])
# 10:04:40 --- Detecting inj1...                         ['conditional', [6, 1], ['_L', 1]])
# 10:04:40 --- Detecting ttl1_on...                      ['conditional', [15, 1], ['_L', 1]])
# 10:04:40 --- Detecting ttl1_off...                     ['conditional', [15, 1], ['_L', 0]])
# 10:04:40 --- Detecting x_coordinates...                ['simple', [9, 1], '_Y'])
# 10:04:40 --- Detecting xy_timestamps...                ['simple', [9, 1], 'TIME'])
# 10:04:40 --- Detecting HLED...                         ['ON_OFF', 'both', ['hled_on', 'hled_off']])
# 10:04:40 --- Detecting LED1...                         ['ON_OFF', 'both', ['led1_on', 'led1_off']])
# 10:04:40 --- Detecting LED2...                         ['ON_OFF', 'both', ['led2_on', 'led2_off']])
# 10:04:40 --- Detecting TTL1...                         ['ON_OFF', 'both', ['ttl1_on', 'ttl1_off']])
# 10:04:40 --- Detecting rec_start...                    ['indexed', 'ttl1_on', 1])
# 10:04:40 --- Detecting DARK...                         ['INTERSECTION', ['HLED_OFF', 'LED1_OFF', 'LED2_OFF']])
# 10:04:40 --- Detecting DNI...                          ['NEAR_EVENT', 'DARK', 'inj1', 5])
# 10:04:40 --- Detecting TO_DARK...                      ['DURATION', 'DNI', '<', 45])
# 10:04:40 --- Detecting TIMEOUT...                      ['UNION', ['LED1_ON', 'TO_DARK']])
# 10:04:40 --- Detecting NOTO_DARK...                    ['INTERSECTION', ['DARK', '~TIMEOUT']])
# 10:04:40 --- Detecting hled_on_start...                ['boundary', 'start', 'HLED_ON'])
# 10:04:40 --- Detecting hled_on_end...                  ['boundary', 'end', 'HLED_ON'])
# 10:04:40 --- Detecting switch_d_nd...                  ['iselement', 'hled_on_start', 'LED2_ON'])
# 10:04:40 --- Detecting switch_to_nd...                 ['iselement', 'hled_on_start', 'TIMEOUT'])
# 10:04:40 --- Detecting switch_dto_nd...                ['combination', ['switch_d_nd', 'switch_to_nd']])
# 10:04:40 --- Detecting switch_nd_d...                  ['iselement', 'hled_on_end', 'LED2_ON'])
# 10:04:40 --- Detecting switch_between...               ['timerestricted', 'switch_dto_nd', [100, 3400]])
# 10:04:40 --- Detecting switch_1...                     ['indexed', 'switch_between', 1])
# 10:04:40 --- Detecting np_effective1...                ['iselement', 'np1', '~HLED_ON'])
# 10:04:40 --- Detecting np_effective2...                ['iselement', 'np_effective1', '~TIMEOUT'])
# 10:04:40 --- Detecting np1_n...                        ['generative', 'np_effective2', 5])
# 10:04:40 --- Detecting D_n...                          ['GENERATIVE', 'HLED_OFF'])
# 10:04:40 --- Detecting ND_n...                         ['GENERATIVE', 'HLED_ON'])
# 10:04:40 --- Detecting ND_first...                     ['NEAR_EVENT', 'HLED_ON', 'switch_1', 1])
# 10:04:40 --- Importing finished in 0.051 seconds
#
# 10:04:40 --- Importing ../../DATA/FIBER_SAMPLE//AD21R_rat_2_SA_j42/rat2sa211082021_0 - Copy.csv...
# 10:04:41 --- Found 5 separate recordings.
# 10:04:41 --- Analyzing peaks...
# 10:04:41 --- Normalizing recording 1 with method 'F'
# 10:04:41 ---
# 10:04:41 --- Normalizing recording 2 with method 'F'
# 10:04:41 ---
# C:\Users\mceau\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\mceau\Anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 10:04:42 --- Normalizing recording 3 with method 'F'
# 10:04:42 ---
# 10:04:42 --- Normalizing recording 4 with method 'F'
# 10:04:42 ---
# 10:04:42 --- Normalizing recording 5 with method 'F'
# 10:04:42 ---
# 10:04:42 --- Importing of ../../DATA/FIBER_SAMPLE//AD21R_rat_2_SA_j42/rat2sa211082021_0 - Copy.csv finished in 1.7889373302459717 seconds
# 10:04:42 ---
# Importing folder AK20R_rat_3_SA_j17...
# 10:04:42 --- IMPORTING ../../DATA/FIBER_SAMPLE//AK20R_rat_3_SA_j17/bsa19112020c20_01.dat...
# 10:04:42 --- Detecting hled_on...                      ['conditional', [1, 1], ['_P', 1]])
# 10:04:42 --- Detecting hled_off...                     ['conditional', [1, 1], ['_P', 0]])
# 10:04:42 --- Detecting led1_on...                      ['conditional', [1, 2], ['_P', 1]])
# 10:04:42 --- Detecting led1_off...                     ['conditional', [1, 2], ['_P', 0]])
# 10:04:42 --- Detecting led2_on...                      ['conditional', [1, 3], ['_P', 1]])
# 10:04:42 --- Detecting led2_off...                     ['conditional', [1, 3], ['_P', 0]])
# 10:04:42 --- Detecting np1...                          ['conditional', [3, 1], ['_V', 1]])
# 10:04:42 --- Detecting np2...                          ['conditional', [3, 2], ['_V', 1]])
# 10:04:42 --- Detecting inj1...                         ['conditional', [6, 1], ['_L', 1]])
# 10:04:42 --- Detecting ttl1_on...                      ['conditional', [15, 1], ['_L', 1]])
# 10:04:42 --- Detecting ttl1_off...                     ['conditional', [15, 1], ['_L', 0]])
# 10:04:42 --- Detecting x_coordinates...                ['simple', [9, 1], '_Y'])
# 10:04:42 --- Detecting xy_timestamps...                ['simple', [9, 1], 'TIME'])
# 10:04:42 --- Detecting HLED...                         ['ON_OFF', 'both', ['hled_on', 'hled_off']])
# 10:04:42 --- Detecting LED1...                         ['ON_OFF', 'both', ['led1_on', 'led1_off']])
# 10:04:42 --- Detecting LED2...                         ['ON_OFF', 'both', ['led2_on', 'led2_off']])
# 10:04:42 --- Detecting TTL1...                         ['ON_OFF', 'both', ['ttl1_on', 'ttl1_off']])
# 10:04:42 --- Detecting rec_start...                    ['indexed', 'ttl1_on', 1])
# 10:04:42 --- Detecting DARK...                         ['INTERSECTION', ['HLED_OFF', 'LED1_OFF', 'LED2_OFF']])
# 10:04:42 --- Detecting DNI...                          ['NEAR_EVENT', 'DARK', 'inj1', 5])
# 10:04:42 --- Detecting TO_DARK...                      ['DURATION', 'DNI', '<', 45])
# 10:04:42 --- Detecting TIMEOUT...                      ['UNION', ['LED1_ON', 'TO_DARK']])
# 10:04:42 --- Detecting NOTO_DARK...                    ['INTERSECTION', ['DARK', '~TIMEOUT']])
# 10:04:42 --- Detecting hled_on_start...                ['boundary', 'start', 'HLED_ON'])
# 10:04:42 --- Detecting hled_on_end...                  ['boundary', 'end', 'HLED_ON'])
# 10:04:42 --- Detecting switch_d_nd...                  ['iselement', 'hled_on_start', 'LED2_ON'])
# 10:04:42 --- Detecting switch_to_nd...                 ['iselement', 'hled_on_start', 'TIMEOUT'])
# 10:04:42 --- Detecting switch_dto_nd...                ['combination', ['switch_d_nd', 'switch_to_nd']])
# 10:04:42 --- Detecting switch_nd_d...                  ['iselement', 'hled_on_end', 'LED2_ON'])
# 10:04:42 --- Detecting switch_between...               ['timerestricted', 'switch_dto_nd', [100, 3400]])
# 10:04:42 --- Detecting switch_1...                     ['indexed', 'switch_between', 1])
# 10:04:42 --- Detecting np_effective1...                ['iselement', 'np1', '~HLED_ON'])
# 10:04:42 --- Detecting np_effective2...                ['iselement', 'np_effective1', '~TIMEOUT'])
# 10:04:42 --- Detecting np1_n...                        ['generative', 'np_effective2', 5])
# 10:04:42 --- Detecting D_n...                          ['GENERATIVE', 'HLED_OFF'])
# 10:04:42 --- Detecting ND_n...                         ['GENERATIVE', 'HLED_ON'])
# 10:04:42 --- Detecting ND_first...                     ['NEAR_EVENT', 'HLED_ON', 'switch_1', 1])
# 10:04:42 --- Importing finished in 0.033 seconds
#
# 10:04:42 --- Importing ../../DATA/FIBER_SAMPLE//AK20R_rat_3_SA_j17/rat 3 AK20R SESSION 19 11 2020_0.csv...
# 10:04:43 --- Found 4 separate recordings.
# 10:04:43 --- Analyzing peaks...
# 10:04:43 --- Normalizing recording 1 with method 'F'
# 10:04:43 ---
# 10:04:43 --- Normalizing recording 2 with method 'F'
# 10:04:43 ---
# 10:04:43 --- Normalizing recording 3 with method 'F'
# 10:04:43 ---
# 10:04:43 --- Normalizing recording 4 with method 'F'
# 10:04:43 ---
# 10:04:43 --- Importing of ../../DATA/FIBER_SAMPLE//AK20R_rat_3_SA_j17/rat 3 AK20R SESSION 19 11 2020_0.csv finished in 1.1743028163909912 seconds
# 10:04:43 ---
# Importing folder AL21R_rat_3_NCIBSL_j37...
# 10:04:43 --- IMPORTING ../../DATA/FIBER_SAMPLE//AL21R_rat_3_NCIBSL_j37/bsa01122021c20_02.dat...
# 10:04:43 --- Detecting hled_on...                      ['conditional', [1, 1], ['_P', 1]])
# 10:04:43 --- Detecting hled_off...                     ['conditional', [1, 1], ['_P', 0]])
# 10:04:43 --- Detecting led1_on...                      ['conditional', [1, 2], ['_P', 1]])
# 10:04:43 --- Detecting led1_off...                     ['conditional', [1, 2], ['_P', 0]])
# 10:04:43 --- Detecting led2_on...                      ['conditional', [1, 3], ['_P', 1]])
# 10:04:43 --- Detecting led2_off...                     ['conditional', [1, 3], ['_P', 0]])
# 10:04:43 --- Detecting np1...                          ['conditional', [3, 1], ['_V', 1]])
# 10:04:43 --- Detecting np2...                          ['conditional', [3, 2], ['_V', 1]])
# 10:04:43 --- Detecting inj1...                         ['conditional', [6, 1], ['_L', 1]])
# 10:04:43 --- Detecting ttl1_on...                      ['conditional', [15, 1], ['_L', 1]])
# 10:04:43 --- Detecting ttl1_off...                     ['conditional', [15, 1], ['_L', 0]])
# 10:04:43 --- Detecting x_coordinates...                ['simple', [9, 1], '_Y'])
# 10:04:43 --- Detecting xy_timestamps...                ['simple', [9, 1], 'TIME'])
# 10:04:43 --- Detecting HLED...                         ['ON_OFF', 'both', ['hled_on', 'hled_off']])
# 10:04:43 --- Detecting LED1...                         ['ON_OFF', 'both', ['led1_on', 'led1_off']])
# 10:04:43 --- Detecting LED2...                         ['ON_OFF', 'both', ['led2_on', 'led2_off']])
# 10:04:43 --- Detecting TTL1...                         ['ON_OFF', 'both', ['ttl1_on', 'ttl1_off']])
# 10:04:43 --- Detecting rec_start...                    ['indexed', 'ttl1_on', 1])
# 10:04:43 --- Detecting DARK...                         ['INTERSECTION', ['HLED_OFF', 'LED1_OFF', 'LED2_OFF']])
# 10:04:43 --- Detecting DNI...                          ['NEAR_EVENT', 'DARK', 'inj1', 5])
# 10:04:43 --- Detecting TO_DARK...                      ['DURATION', 'DNI', '<', 45])
# 10:04:43 --- Detecting TIMEOUT...                      ['UNION', ['LED1_ON', 'TO_DARK']])
# 10:04:43 --- Detecting NOTO_DARK...                    ['INTERSECTION', ['DARK', '~TIMEOUT']])
# 10:04:43 --- Detecting hled_on_start...                ['boundary', 'start', 'HLED_ON'])
# 10:04:43 --- Detecting hled_on_end...                  ['boundary', 'end', 'HLED_ON'])
# 10:04:43 --- Detecting switch_d_nd...                  ['iselement', 'hled_on_start', 'LED2_ON'])
# 10:04:43 --- Detecting switch_to_nd...                 ['iselement', 'hled_on_start', 'TIMEOUT'])
# 10:04:43 --- Detecting switch_dto_nd...                ['combination', ['switch_d_nd', 'switch_to_nd']])
# 10:04:43 --- Detecting switch_nd_d...                  ['iselement', 'hled_on_end', 'LED2_ON'])
# 10:04:43 --- Detecting switch_between...               ['timerestricted', 'switch_dto_nd', [100, 3400]])
# 10:04:43 --- Detecting switch_1...                     ['indexed', 'switch_between', 1])
# 10:04:43 --- Detecting np_effective1...                ['iselement', 'np1', '~HLED_ON'])
# 10:04:43 --- Detecting np_effective2...                ['iselement', 'np_effective1', '~TIMEOUT'])
# 10:04:43 --- Detecting np1_n...                        ['generative', 'np_effective2', 5])
# 10:04:43 --- Detecting D_n...                          ['GENERATIVE', 'HLED_OFF'])
# 10:04:43 --- Detecting ND_n...                         ['GENERATIVE', 'HLED_ON'])
# 10:04:43 --- Detecting ND_first...                     ['NEAR_EVENT', 'HLED_ON', 'switch_1', 1])
# 10:04:43 --- Importing finished in 0.037 seconds
#
# 10:04:43 --- Importing ../../DATA/FIBER_SAMPLE//AL21R_rat_3_NCIBSL_j37/AL21Rrat3nciBSL101122021_0.csv...
# 10:04:44 --- Found 1 separate recordings.
# 10:04:44 --- Analyzing peaks...
# 10:04:44 --- Normalizing recording 1 with method 'F'
# 10:04:44 ---
# 10:04:47 --- Importing of ../../DATA/FIBER_SAMPLE//AL21R_rat_3_NCIBSL_j37/AL21Rrat3nciBSL101122021_0.csv finished in 3.298457145690918 seconds
# 10:04:47 ---
# Importing folder AS21R_rat_10_SA1_j22...
# 10:04:47 --- IMPORTING ../../DATA/FIBER_SAMPLE//AS21R_rat_10_SA1_j22/bsa02032022c20_01.dat...
# 10:04:47 --- Detecting hled_on...                      ['conditional', [1, 1], ['_P', 1]])
# 10:04:47 --- Detecting hled_off...                     ['conditional', [1, 1], ['_P', 0]])
# 10:04:47 --- Detecting led1_on...                      ['conditional', [1, 2], ['_P', 1]])
# 10:04:47 --- Detecting led1_off...                     ['conditional', [1, 2], ['_P', 0]])
# 10:04:47 --- Detecting led2_on...                      ['conditional', [1, 3], ['_P', 1]])
# 10:04:47 --- Detecting led2_off...                     ['conditional', [1, 3], ['_P', 0]])
# 10:04:47 --- Detecting np1...                          ['conditional', [3, 1], ['_V', 1]])
# 10:04:47 --- Detecting np2...                          ['conditional', [3, 2], ['_V', 1]])
# 10:04:47 --- Detecting inj1...                         ['conditional', [6, 1], ['_L', 1]])
# 10:04:47 --- Detecting ttl1_on...                      ['conditional', [15, 1], ['_L', 1]])
# 10:04:47 --- Detecting ttl1_off...                     ['conditional', [15, 1], ['_L', 0]])
# 10:04:47 --- Detecting x_coordinates...                ['simple', [9, 1], '_Y'])
# 10:04:47 --- Detecting xy_timestamps...                ['simple', [9, 1], 'TIME'])
# 10:04:47 --- Detecting HLED...                         ['ON_OFF', 'both', ['hled_on', 'hled_off']])
# 10:04:47 --- Detecting LED1...                         ['ON_OFF', 'both', ['led1_on', 'led1_off']])
# 10:04:47 --- Detecting LED2...                         ['ON_OFF', 'both', ['led2_on', 'led2_off']])
# 10:04:47 --- Detecting TTL1...                         ['ON_OFF', 'both', ['ttl1_on', 'ttl1_off']])
# 10:04:47 --- Detecting rec_start...                    ['indexed', 'ttl1_on', 1])
# 10:04:47 --- Detecting DARK...                         ['INTERSECTION', ['HLED_OFF', 'LED1_OFF', 'LED2_OFF']])
# 10:04:47 --- Detecting DNI...                          ['NEAR_EVENT', 'DARK', 'inj1', 5])
# 10:04:47 --- Detecting TO_DARK...                      ['DURATION', 'DNI', '<', 45])
# 10:04:47 --- Detecting TIMEOUT...                      ['UNION', ['LED1_ON', 'TO_DARK']])
# 10:04:47 --- Detecting NOTO_DARK...                    ['INTERSECTION', ['DARK', '~TIMEOUT']])
# 10:04:47 --- Detecting hled_on_start...                ['boundary', 'start', 'HLED_ON'])
# 10:04:47 --- Detecting hled_on_end...                  ['boundary', 'end', 'HLED_ON'])
# 10:04:47 --- Detecting switch_d_nd...                  ['iselement', 'hled_on_start', 'LED2_ON'])
# 10:04:47 --- Detecting switch_to_nd...                 ['iselement', 'hled_on_start', 'TIMEOUT'])
# 10:04:47 --- Detecting switch_dto_nd...                ['combination', ['switch_d_nd', 'switch_to_nd']])
# 10:04:47 --- Detecting switch_nd_d...                  ['iselement', 'hled_on_end', 'LED2_ON'])
# 10:04:47 --- Detecting switch_between...               ['timerestricted', 'switch_dto_nd', [100, 3400]])
# 10:04:47 --- Detecting switch_1...                     ['indexed', 'switch_between', 1])
# 10:04:47 --- Detecting np_effective1...                ['iselement', 'np1', '~HLED_ON'])
# 10:04:47 --- Detecting np_effective2...                ['iselement', 'np_effective1', '~TIMEOUT'])
# 10:04:47 --- Detecting np1_n...                        ['generative', 'np_effective2', 5])
# 10:04:47 --- Detecting D_n...                          ['GENERATIVE', 'HLED_OFF'])
# 10:04:47 --- Detecting ND_n...                         ['GENERATIVE', 'HLED_ON'])
# 10:04:47 --- Detecting ND_first...                     ['NEAR_EVENT', 'HLED_ON', 'switch_1', 1])
# 10:04:47 --- Importing finished in 0.04 seconds
#
# 10:04:47 --- Importing ../../DATA/FIBER_SAMPLE//AS21R_rat_10_SA1_j22/AS21RSA1Rat1002032022_0.csv...
# 10:04:48 --- Found 5 separate recordings.
# 10:04:48 --- Analyzing peaks...
# 10:04:48 --- Normalizing recording 1 with method 'F'
# 10:04:48 ---
# 10:04:48 --- Normalizing recording 2 with method 'F'
# 10:04:48 ---
# 10:04:48 --- Normalizing recording 3 with method 'F'
# 10:04:48 ---
# 10:04:48 --- Normalizing recording 4 with method 'F'
# 10:04:48 ---
# 10:04:48 --- Normalizing recording 5 with method 'F'
# 10:04:48 ---
# 10:04:49 --- Importing of ../../DATA/FIBER_SAMPLE//AS21R_rat_10_SA1_j22/AS21RSA1Rat1002032022_0.csv finished in 1.768949031829834 seconds
# 10:04:49 ---
# Importing folder AS21R_rat_11_SA5_j33...
# 10:04:49 --- IMPORTING ../../DATA/FIBER_SAMPLE//AS21R_rat_11_SA5_j33/bsa17032022c20_01.dat...
# 10:04:49 --- Detecting hled_on...                      ['conditional', [1, 1], ['_P', 1]])
# 10:04:49 --- Detecting hled_off...                     ['conditional', [1, 1], ['_P', 0]])
# 10:04:49 --- Detecting led1_on...                      ['conditional', [1, 2], ['_P', 1]])
# 10:04:49 --- Detecting led1_off...                     ['conditional', [1, 2], ['_P', 0]])
# 10:04:49 --- Detecting led2_on...                      ['conditional', [1, 3], ['_P', 1]])
# 10:04:49 --- Detecting led2_off...                     ['conditional', [1, 3], ['_P', 0]])
# 10:04:49 --- Detecting np1...                          ['conditional', [3, 1], ['_V', 1]])
# 10:04:49 --- Detecting np2...                          ['conditional', [3, 2], ['_V', 1]])
# 10:04:49 --- Detecting inj1...                         ['conditional', [6, 1], ['_L', 1]])
# 10:04:49 --- Detecting ttl1_on...                      ['conditional', [15, 1], ['_L', 1]])
# 10:04:49 --- Detecting ttl1_off...                     ['conditional', [15, 1], ['_L', 0]])
# 10:04:49 --- Detecting x_coordinates...                ['simple', [9, 1], '_Y'])
# 10:04:49 --- Detecting xy_timestamps...                ['simple', [9, 1], 'TIME'])
# 10:04:49 --- Detecting HLED...                         ['ON_OFF', 'both', ['hled_on', 'hled_off']])
# 10:04:49 --- Detecting LED1...                         ['ON_OFF', 'both', ['led1_on', 'led1_off']])
# 10:04:49 --- Detecting LED2...                         ['ON_OFF', 'both', ['led2_on', 'led2_off']])
# 10:04:49 --- Detecting TTL1...                         ['ON_OFF', 'both', ['ttl1_on', 'ttl1_off']])
# 10:04:49 --- Detecting rec_start...                    ['indexed', 'ttl1_on', 1])
# 10:04:49 --- Detecting DARK...                         ['INTERSECTION', ['HLED_OFF', 'LED1_OFF', 'LED2_OFF']])
# 10:04:49 --- Detecting DNI...                          ['NEAR_EVENT', 'DARK', 'inj1', 5])
# 10:04:49 --- Detecting TO_DARK...                      ['DURATION', 'DNI', '<', 45])
# 10:04:49 --- Detecting TIMEOUT...                      ['UNION', ['LED1_ON', 'TO_DARK']])
# 10:04:49 --- Detecting NOTO_DARK...                    ['INTERSECTION', ['DARK', '~TIMEOUT']])
# 10:04:49 --- Detecting hled_on_start...                ['boundary', 'start', 'HLED_ON'])
# 10:04:49 --- Detecting hled_on_end...                  ['boundary', 'end', 'HLED_ON'])
# 10:04:49 --- Detecting switch_d_nd...                  ['iselement', 'hled_on_start', 'LED2_ON'])
# 10:04:49 --- Detecting switch_to_nd...                 ['iselement', 'hled_on_start', 'TIMEOUT'])
# 10:04:49 --- Detecting switch_dto_nd...                ['combination', ['switch_d_nd', 'switch_to_nd']])
# 10:04:49 --- Detecting switch_nd_d...                  ['iselement', 'hled_on_end', 'LED2_ON'])
# 10:04:49 --- Detecting switch_between...               ['timerestricted', 'switch_dto_nd', [100, 3400]])
# 10:04:49 --- Detecting switch_1...                     ['indexed', 'switch_between', 1])
# 10:04:49 --- Detecting np_effective1...                ['iselement', 'np1', '~HLED_ON'])
# 10:04:49 --- Detecting np_effective2...                ['iselement', 'np_effective1', '~TIMEOUT'])
# 10:04:49 --- Detecting np1_n...                        ['generative', 'np_effective2', 5])
# 10:04:49 --- Detecting D_n...                          ['GENERATIVE', 'HLED_OFF'])
# 10:04:49 --- Detecting ND_n...                         ['GENERATIVE', 'HLED_ON'])
# 10:04:49 --- Detecting ND_first...                     ['NEAR_EVENT', 'HLED_ON', 'switch_1', 1])
# 10:04:49 --- Importing finished in 0.046 seconds
#
# 10:04:49 --- Importing ../../DATA/FIBER_SAMPLE//AS21R_rat_11_SA5_j33/AS21RSA5Rat1117032022_0.csv...
# 10:04:49 --- Found 5 separate recordings.
# 10:04:49 --- Analyzing peaks...
# 10:04:49 --- Normalizing recording 1 with method 'F'
# 10:04:49 ---
# 10:04:50 --- Normalizing recording 2 with method 'F'
# 10:04:50 ---
# 10:04:50 --- Normalizing recording 3 with method 'F'
# 10:04:50 ---
# 10:04:50 --- Normalizing recording 4 with method 'F'
# 10:04:50 ---
# 10:04:50 --- Normalizing recording 5 with method 'F'
# 10:04:50 ---
# 10:04:50 --- Importing of ../../DATA/FIBER_SAMPLE//AS21R_rat_11_SA5_j33/AS21RSA5Rat1117032022_0.csv finished in 1.8499019145965576 seconds
# 10:04:50 ---
# Importing folder AS21R_rat_12_SA4...
# 10:04:50 --- IMPORTING ../../DATA/FIBER_SAMPLE//AS21R_rat_12_SA4/bsa10032022c20_02.dat...
# 10:04:50 --- Detecting hled_on...                      ['conditional', [1, 1], ['_P', 1]])
# 10:04:50 --- Detecting hled_off...                     ['conditional', [1, 1], ['_P', 0]])
# 10:04:50 --- Detecting led1_on...                      ['conditional', [1, 2], ['_P', 1]])
# 10:04:50 --- Detecting led1_off...                     ['conditional', [1, 2], ['_P', 0]])
# 10:04:50 --- Detecting led2_on...                      ['conditional', [1, 3], ['_P', 1]])
# 10:04:50 --- Detecting led2_off...                     ['conditional', [1, 3], ['_P', 0]])
# 10:04:50 --- Detecting np1...                          ['conditional', [3, 1], ['_V', 1]])
# 10:04:50 --- Detecting np2...                          ['conditional', [3, 2], ['_V', 1]])
# 10:04:50 --- Detecting inj1...                         ['conditional', [6, 1], ['_L', 1]])
# 10:04:51 --- Detecting ttl1_on...                      ['conditional', [15, 1], ['_L', 1]])
# 10:04:51 --- Detecting ttl1_off...                     ['conditional', [15, 1], ['_L', 0]])
# 10:04:51 --- Detecting x_coordinates...                ['simple', [9, 1], '_Y'])
# 10:04:51 --- Detecting xy_timestamps...                ['simple', [9, 1], 'TIME'])
# 10:04:51 --- Detecting HLED...                         ['ON_OFF', 'both', ['hled_on', 'hled_off']])
# 10:04:51 --- Detecting LED1...                         ['ON_OFF', 'both', ['led1_on', 'led1_off']])
# 10:04:51 --- Detecting LED2...                         ['ON_OFF', 'both', ['led2_on', 'led2_off']])
# 10:04:51 --- Detecting TTL1...                         ['ON_OFF', 'both', ['ttl1_on', 'ttl1_off']])
# 10:04:51 --- Detecting rec_start...                    ['indexed', 'ttl1_on', 1])
# 10:04:51 --- Detecting DARK...                         ['INTERSECTION', ['HLED_OFF', 'LED1_OFF', 'LED2_OFF']])
# 10:04:51 --- Detecting DNI...                          ['NEAR_EVENT', 'DARK', 'inj1', 5])
# 10:04:51 --- Detecting TO_DARK...                      ['DURATION', 'DNI', '<', 45])
# 10:04:51 --- Detecting TIMEOUT...                      ['UNION', ['LED1_ON', 'TO_DARK']])
# 10:04:51 --- Detecting NOTO_DARK...                    ['INTERSECTION', ['DARK', '~TIMEOUT']])
# 10:04:51 --- Detecting hled_on_start...                ['boundary', 'start', 'HLED_ON'])
# 10:04:51 --- Detecting hled_on_end...                  ['boundary', 'end', 'HLED_ON'])
# 10:04:51 --- Detecting switch_d_nd...                  ['iselement', 'hled_on_start', 'LED2_ON'])
# 10:04:51 --- Detecting switch_to_nd...                 ['iselement', 'hled_on_start', 'TIMEOUT'])
# 10:04:51 --- Detecting switch_dto_nd...                ['combination', ['switch_d_nd', 'switch_to_nd']])
# 10:04:51 --- Detecting switch_nd_d...                  ['iselement', 'hled_on_end', 'LED2_ON'])
# 10:04:51 --- Detecting switch_between...               ['timerestricted', 'switch_dto_nd', [100, 3400]])
# 10:04:51 --- Detecting switch_1...                     ['indexed', 'switch_between', 1])
# 10:04:51 --- Detecting np_effective1...                ['iselement', 'np1', '~HLED_ON'])
# 10:04:51 --- Detecting np_effective2...                ['iselement', 'np_effective1', '~TIMEOUT'])
# 10:04:51 --- Detecting np1_n...                        ['generative', 'np_effective2', 5])
# 10:04:51 --- Detecting D_n...                          ['GENERATIVE', 'HLED_OFF'])
# 10:04:51 --- Detecting ND_n...                         ['GENERATIVE', 'HLED_ON'])
# 10:04:51 --- Detecting ND_first...                     ['NEAR_EVENT', 'HLED_ON', 'switch_1', 1])
# 10:04:51 --- Importing finished in 0.048 seconds
#
# 10:04:51 --- Importing ../../DATA/FIBER_SAMPLE//AS21R_rat_12_SA4/AS21RSA4Rat1210032022_0.csv...
# 10:04:51 --- Found 2 separate recordings.
# 10:04:51 --- Analyzing peaks...
# 10:04:51 --- Normalizing recording 1 with method 'F'
# 10:04:51 ---
# 10:04:51 --- Normalizing recording 2 with method 'F'
# 10:04:51 ---
# 10:04:51 --- Importing of ../../DATA/FIBER_SAMPLE//AS21R_rat_12_SA4/AS21RSA4Rat1210032022_0.csv finished in 0.4117560386657715 seconds
# 10:04:51 ---
# Importing folder AS21R_rat_5_SA6_j37...
# 10:04:51 --- IMPORTING ../../DATA/FIBER_SAMPLE//AS21R_rat_5_SA6_j37/bsa23032022c20_01.dat...
# 10:04:51 --- Detecting hled_on...                      ['conditional', [1, 1], ['_P', 1]])
# 10:04:51 --- Detecting hled_off...                     ['conditional', [1, 1], ['_P', 0]])
# 10:04:51 --- Detecting led1_on...                      ['conditional', [1, 2], ['_P', 1]])
# 10:04:51 --- Detecting led1_off...                     ['conditional', [1, 2], ['_P', 0]])
# 10:04:51 --- Detecting led2_on...                      ['conditional', [1, 3], ['_P', 1]])
# 10:04:51 --- Detecting led2_off...                     ['conditional', [1, 3], ['_P', 0]])
# 10:04:51 --- Detecting np1...                          ['conditional', [3, 1], ['_V', 1]])
# 10:04:51 --- Detecting np2...                          ['conditional', [3, 2], ['_V', 1]])
# 10:04:51 --- Detecting inj1...                         ['conditional', [6, 1], ['_L', 1]])
# 10:04:51 --- Detecting ttl1_on...                      ['conditional', [15, 1], ['_L', 1]])
# 10:04:51 --- Detecting ttl1_off...                     ['conditional', [15, 1], ['_L', 0]])
# 10:04:51 --- Detecting x_coordinates...                ['simple', [9, 1], '_Y'])
# 10:04:51 --- Detecting xy_timestamps...                ['simple', [9, 1], 'TIME'])
# 10:04:51 --- Detecting HLED...                         ['ON_OFF', 'both', ['hled_on', 'hled_off']])
# 10:04:51 --- Detecting LED1...                         ['ON_OFF', 'both', ['led1_on', 'led1_off']])
# 10:04:51 --- Detecting LED2...                         ['ON_OFF', 'both', ['led2_on', 'led2_off']])
# 10:04:51 --- Detecting TTL1...                         ['ON_OFF', 'both', ['ttl1_on', 'ttl1_off']])
# 10:04:51 --- Detecting rec_start...                    ['indexed', 'ttl1_on', 1])
# 10:04:51 --- Detecting DARK...                         ['INTERSECTION', ['HLED_OFF', 'LED1_OFF', 'LED2_OFF']])
# 10:04:51 --- Detecting DNI...                          ['NEAR_EVENT', 'DARK', 'inj1', 5])
# 10:04:51 --- Detecting TO_DARK...                      ['DURATION', 'DNI', '<', 45])
# 10:04:51 --- Detecting TIMEOUT...                      ['UNION', ['LED1_ON', 'TO_DARK']])
# 10:04:51 --- Detecting NOTO_DARK...                    ['INTERSECTION', ['DARK', '~TIMEOUT']])
# 10:04:51 --- Detecting hled_on_start...                ['boundary', 'start', 'HLED_ON'])
# 10:04:51 --- Detecting hled_on_end...                  ['boundary', 'end', 'HLED_ON'])
# 10:04:51 --- Detecting switch_d_nd...                  ['iselement', 'hled_on_start', 'LED2_ON'])
# 10:04:51 --- Detecting switch_to_nd...                 ['iselement', 'hled_on_start', 'TIMEOUT'])
# 10:04:51 --- Detecting switch_dto_nd...                ['combination', ['switch_d_nd', 'switch_to_nd']])
# 10:04:51 --- Detecting switch_nd_d...                  ['iselement', 'hled_on_end', 'LED2_ON'])
# 10:04:51 --- Detecting switch_between...               ['timerestricted', 'switch_dto_nd', [100, 3400]])
# 10:04:51 --- Detecting switch_1...                     ['indexed', 'switch_between', 1])
# 10:04:51 --- Detecting np_effective1...                ['iselement', 'np1', '~HLED_ON'])
# 10:04:51 --- Detecting np_effective2...                ['iselement', 'np_effective1', '~TIMEOUT'])
# 10:04:51 --- Detecting np1_n...                        ['generative', 'np_effective2', 5])
# 10:04:51 --- Detecting D_n...                          ['GENERATIVE', 'HLED_OFF'])
# 10:04:51 --- Detecting ND_n...                         ['GENERATIVE', 'HLED_ON'])
# 10:04:51 --- Detecting ND_first...                     ['NEAR_EVENT', 'HLED_ON', 'switch_1', 1])
# 10:04:51 --- Importing finished in 0.048 seconds
#
# 10:04:51 --- Importing ../../DATA/FIBER_SAMPLE//AS21R_rat_5_SA6_j37/AS21RSA6Rat523032022_0.csv...
# 10:04:52 --- Found 5 separate recordings.
# 10:04:52 --- Analyzing peaks...
# 10:04:52 --- Normalizing recording 1 with method 'F'
# 10:04:52 ---
# 10:04:52 --- Normalizing recording 2 with method 'F'
# 10:04:52 ---
# 10:04:52 --- Normalizing recording 3 with method 'F'
# 10:04:52 ---
# 10:04:52 --- Normalizing recording 4 with method 'F'
# 10:04:52 ---
# 10:04:53 --- Normalizing recording 5 with method 'F'
# 10:04:53 ---
# 10:04:53 --- Importing of ../../DATA/FIBER_SAMPLE//AS21R_rat_5_SA6_j37/AS21RSA6Rat523032022_0.csv finished in 1.784940481185913 seconds
# 10:04:53 ---
# Importing folder AS21R_rat_8_SA1...
# 10:04:53 --- IMPORTING ../../DATA/FIBER_SAMPLE//AS21R_rat_8_SA1/bsa03032022c20_02.dat...
# 10:04:53 --- Detecting hled_on...                      ['conditional', [1, 1], ['_P', 1]])
# 10:04:53 --- Detecting hled_off...                     ['conditional', [1, 1], ['_P', 0]])
# 10:04:53 --- Detecting led1_on...                      ['conditional', [1, 2], ['_P', 1]])
# 10:04:53 --- Detecting led1_off...                     ['conditional', [1, 2], ['_P', 0]])
# 10:04:53 --- Detecting led2_on...                      ['conditional', [1, 3], ['_P', 1]])
# 10:04:53 --- Detecting led2_off...                     ['conditional', [1, 3], ['_P', 0]])
# 10:04:53 --- Detecting np1...                          ['conditional', [3, 1], ['_V', 1]])
# 10:04:53 --- Detecting np2...                          ['conditional', [3, 2], ['_V', 1]])
# 10:04:53 --- Detecting inj1...                         ['conditional', [6, 1], ['_L', 1]])
# 10:04:53 --- Detecting ttl1_on...                      ['conditional', [15, 1], ['_L', 1]])
# 10:04:53 --- Detecting ttl1_off...                     ['conditional', [15, 1], ['_L', 0]])
# 10:04:53 --- Detecting x_coordinates...                ['simple', [9, 1], '_Y'])
# 10:04:53 --- Detecting xy_timestamps...                ['simple', [9, 1], 'TIME'])
# 10:04:53 --- Detecting HLED...                         ['ON_OFF', 'both', ['hled_on', 'hled_off']])
# 10:04:53 --- Detecting LED1...                         ['ON_OFF', 'both', ['led1_on', 'led1_off']])
# 10:04:53 --- Detecting LED2...                         ['ON_OFF', 'both', ['led2_on', 'led2_off']])
# 10:04:53 --- Detecting TTL1...                         ['ON_OFF', 'both', ['ttl1_on', 'ttl1_off']])
# 10:04:53 --- Detecting rec_start...                    ['indexed', 'ttl1_on', 1])
# 10:04:53 --- Detecting DARK...                         ['INTERSECTION', ['HLED_OFF', 'LED1_OFF', 'LED2_OFF']])
# 10:04:53 --- Detecting DNI...                          ['NEAR_EVENT', 'DARK', 'inj1', 5])
# 10:04:53 --- Detecting TO_DARK...                      ['DURATION', 'DNI', '<', 45])
# 10:04:53 --- Detecting TIMEOUT...                      ['UNION', ['LED1_ON', 'TO_DARK']])
# 10:04:53 --- Detecting NOTO_DARK...                    ['INTERSECTION', ['DARK', '~TIMEOUT']])
# 10:04:53 --- Detecting hled_on_start...                ['boundary', 'start', 'HLED_ON'])
# 10:04:53 --- Detecting hled_on_end...                  ['boundary', 'end', 'HLED_ON'])
# 10:04:53 --- Detecting switch_d_nd...                  ['iselement', 'hled_on_start', 'LED2_ON'])
# 10:04:53 --- Detecting switch_to_nd...                 ['iselement', 'hled_on_start', 'TIMEOUT'])
# 10:04:53 --- Detecting switch_dto_nd...                ['combination', ['switch_d_nd', 'switch_to_nd']])
# 10:04:53 --- Detecting switch_nd_d...                  ['iselement', 'hled_on_end', 'LED2_ON'])
# 10:04:53 --- Detecting switch_between...               ['timerestricted', 'switch_dto_nd', [100, 3400]])
# 10:04:53 --- Detecting switch_1...                     ['indexed', 'switch_between', 1])
# 10:04:53 --- Detecting np_effective1...                ['iselement', 'np1', '~HLED_ON'])
# 10:04:53 --- Detecting np_effective2...                ['iselement', 'np_effective1', '~TIMEOUT'])
# 10:04:53 --- Detecting np1_n...                        ['generative', 'np_effective2', 5])
# 10:04:53 --- Detecting D_n...                          ['GENERATIVE', 'HLED_OFF'])
# 10:04:53 --- Detecting ND_n...                         ['GENERATIVE', 'HLED_ON'])
# 10:04:53 --- Detecting ND_first...                     ['NEAR_EVENT', 'HLED_ON', 'switch_1', 1])
# 10:04:53 --- Importing finished in 0.045 seconds
#
# 10:04:53 --- Importing ../../DATA/FIBER_SAMPLE//AS21R_rat_8_SA1/AS21RSA1Rat803032022_0.csv...
# 10:04:54 --- Found 5 separate recordings.
# 10:04:54 --- Analyzing peaks...
# 10:04:54 --- Normalizing recording 1 with method 'F'
# 10:04:54 ---
# 10:04:54 --- Normalizing recording 2 with method 'F'
# 10:04:54 ---
# 10:04:54 --- Normalizing recording 3 with method 'F'
# 10:04:54 ---
# 10:04:54 --- Normalizing recording 4 with method 'F'
# 10:04:54 ---
# 10:04:54 --- Normalizing recording 5 with method 'F'
# 10:04:54 ---
# 10:04:55 --- Importing of ../../DATA/FIBER_SAMPLE//AS21R_rat_8_SA1/AS21RSA1Rat803032022_0.csv finished in 1.7669508457183838 seconds
# 10:04:55 ---
# Importing folder AS21R_rat_8_SA3_j27...
# 10:04:55 --- IMPORTING ../../DATA/FIBER_SAMPLE//AS21R_rat_8_SA3_j27/bsa09032022c20_01.dat...
# 10:04:55 --- Detecting hled_on...                      ['conditional', [1, 1], ['_P', 1]])
# 10:04:55 --- Detecting hled_off...                     ['conditional', [1, 1], ['_P', 0]])
# 10:04:55 --- Detecting led1_on...                      ['conditional', [1, 2], ['_P', 1]])
# 10:04:55 --- Detecting led1_off...                     ['conditional', [1, 2], ['_P', 0]])
# 10:04:55 --- Detecting led2_on...                      ['conditional', [1, 3], ['_P', 1]])
# 10:04:55 --- Detecting led2_off...                     ['conditional', [1, 3], ['_P', 0]])
# 10:04:55 --- Detecting np1...                          ['conditional', [3, 1], ['_V', 1]])
# 10:04:55 --- Detecting np2...                          ['conditional', [3, 2], ['_V', 1]])
# 10:04:55 --- Detecting inj1...                         ['conditional', [6, 1], ['_L', 1]])
# 10:04:55 --- Detecting ttl1_on...                      ['conditional', [15, 1], ['_L', 1]])
# 10:04:55 --- Detecting ttl1_off...                     ['conditional', [15, 1], ['_L', 0]])
# 10:04:55 --- Detecting x_coordinates...                ['simple', [9, 1], '_Y'])
# 10:04:55 --- Detecting xy_timestamps...                ['simple', [9, 1], 'TIME'])
# 10:04:55 --- Detecting HLED...                         ['ON_OFF', 'both', ['hled_on', 'hled_off']])
# 10:04:55 --- Detecting LED1...                         ['ON_OFF', 'both', ['led1_on', 'led1_off']])
# 10:04:55 --- Detecting LED2...                         ['ON_OFF', 'both', ['led2_on', 'led2_off']])
# 10:04:55 --- Detecting TTL1...                         ['ON_OFF', 'both', ['ttl1_on', 'ttl1_off']])
# 10:04:55 --- Detecting rec_start...                    ['indexed', 'ttl1_on', 1])
# 10:04:55 --- Detecting DARK...                         ['INTERSECTION', ['HLED_OFF', 'LED1_OFF', 'LED2_OFF']])
# 10:04:55 --- Detecting DNI...                          ['NEAR_EVENT', 'DARK', 'inj1', 5])
# 10:04:55 --- Detecting TO_DARK...                      ['DURATION', 'DNI', '<', 45])
# 10:04:55 --- Detecting TIMEOUT...                      ['UNION', ['LED1_ON', 'TO_DARK']])
# 10:04:55 --- Detecting NOTO_DARK...                    ['INTERSECTION', ['DARK', '~TIMEOUT']])
# 10:04:55 --- Detecting hled_on_start...                ['boundary', 'start', 'HLED_ON'])
# 10:04:55 --- Detecting hled_on_end...                  ['boundary', 'end', 'HLED_ON'])
# 10:04:55 --- Detecting switch_d_nd...                  ['iselement', 'hled_on_start', 'LED2_ON'])
# 10:04:55 --- Detecting switch_to_nd...                 ['iselement', 'hled_on_start', 'TIMEOUT'])
# 10:04:55 --- Detecting switch_dto_nd...                ['combination', ['switch_d_nd', 'switch_to_nd']])
# 10:04:55 --- Detecting switch_nd_d...                  ['iselement', 'hled_on_end', 'LED2_ON'])
# 10:04:55 --- Detecting switch_between...               ['timerestricted', 'switch_dto_nd', [100, 3400]])
# 10:04:55 --- Detecting switch_1...                     ['indexed', 'switch_between', 1])
# 10:04:55 --- Detecting np_effective1...                ['iselement', 'np1', '~HLED_ON'])
# 10:04:55 --- Detecting np_effective2...                ['iselement', 'np_effective1', '~TIMEOUT'])
# 10:04:55 --- Detecting np1_n...                        ['generative', 'np_effective2', 5])
# 10:04:55 --- Detecting D_n...                          ['GENERATIVE', 'HLED_OFF'])
# 10:04:55 --- Detecting ND_n...                         ['GENERATIVE', 'HLED_ON'])
# 10:04:55 --- Detecting ND_first...                     ['NEAR_EVENT', 'HLED_ON', 'switch_1', 1])
# 10:04:55 --- Importing finished in 0.05 seconds
#
# 10:04:55 --- Importing ../../DATA/FIBER_SAMPLE//AS21R_rat_8_SA3_j27/AS21RSA3Rat809032022_0.csv...
# 10:04:55 --- Found 5 separate recordings.
# 10:04:55 --- Analyzing peaks...
# 10:04:55 --- Normalizing recording 1 with method 'F'
# 10:04:55 ---
# 10:04:56 --- Normalizing recording 2 with method 'F'
# 10:04:56 ---
# 10:04:56 --- Normalizing recording 3 with method 'F'
# 10:04:56 ---
# 10:04:56 --- Normalizing recording 4 with method 'F'
# 10:04:56 ---
# 10:04:56 --- Normalizing recording 5 with method 'F'
# 10:04:56 ---
# 10:04:56 --- Importing of ../../DATA/FIBER_SAMPLE//AS21R_rat_8_SA3_j27/AS21RSA3Rat809032022_0.csv finished in 1.7909364700317383 seconds
# 10:04:56 --- Analysing interinfusion intervals...
# 10:04:56 --- Session AS21R_rat_12_SA4 removed, interinfusion = 0.35768571428568197 s
# 10:04:56 --- Session AS21R_rat_8_SA1 removed, interinfusion = 0.3480434782608941 s
# hello
# 10:04:56 --- Extraction finished, 7 sessions (14 files) in 16.067781686782837 seconds

# %%
res = sess.analyze('switch_dto_nd',window=(5,5))
# Out:
# 10:04:57 --- Event timestamps: [2400.    5700.008]
# 10:04:57 --- Choosen interval: [(0.0, 8546.632)] (all)
# 10:04:57 --- Normalizing recording 2 with method 'F'
# 10:04:57 --- Normalizing recording 2 with method 'raw'
# 10:04:57 --- Normalizing recording 5 with method 'F'
# 10:04:57 --- Normalizing recording 5 with method 'raw'
# 10:04:57 --- Event timestamps: [2400.002]
# 10:04:57 --- Choosen interval: [(0.03, 4506.058)] (all)
# 10:04:57 --- Normalizing recording 3 with method 'F'
# 10:04:57 --- Normalizing recording 3 with method 'raw'
# 10:04:57 --- Event timestamps: [2400.]
# 10:04:57 --- Choosen interval: [(0.0, 9000.007)] (all)
# 10:04:57 --- Normalizing recording 1 with method 'F'
# 10:04:57 --- Normalizing recording 1 with method 'raw'
# 10:04:57 --- Event timestamps: [2400.001 5700.003]
# 10:04:57 --- Choosen interval: [(0.034, 9000.086)] (all)
# 10:04:57 --- Normalizing recording 2 with method 'F'
# 10:04:57 --- Normalizing recording 2 with method 'raw'
# 10:04:58 --- Normalizing recording 5 with method 'F'
# 10:04:58 --- Normalizing recording 5 with method 'raw'
# 10:04:58 --- Event timestamps: [2400.007 5700.017]
# 10:04:58 --- Choosen interval: [(0.033, 9000.121)] (all)
# 10:04:58 --- Normalizing recording 2 with method 'F'
# 10:04:58 --- Normalizing recording 2 with method 'raw'
# 10:04:58 --- Normalizing recording 5 with method 'F'
# 10:04:58 --- Normalizing recording 5 with method 'raw'
# 10:04:58 --- Event timestamps: [2400. 5700.]
# 10:04:58 --- Choosen interval: [(0.0, 9000.029)] (all)
# 10:04:58 --- Normalizing recording 2 with method 'F'
# 10:04:58 --- Normalizing recording 2 with method 'raw'
# 10:04:58 --- Normalizing recording 5 with method 'F'
# 10:04:58 --- Normalizing recording 5 with method 'raw'
# 10:04:58 --- Event timestamps: [2400.005 5700.015]
# 10:04:58 --- Choosen interval: [(0.031, 9000.127)] (all)
# 10:04:58 --- Normalizing recording 2 with method 'F'
# 10:04:58 --- Normalizing recording 2 with method 'raw'
# 10:04:58 --- Normalizing recording 5 with method 'F'
# 10:04:58 --- Normalizing recording 5 with method 'raw'
# ============================================================================
#     Analysis took 1.919858694076538 seconds
# ============================================================================

# %%
res.info
# Out:
# <obj>.WINDOW
# <obj>.dict
# <obj>.epoch
# <obj>.event_name
# <obj>.exclude_list
# <obj>.key
# <obj>.type
# <obj>.verbosity

# %%
def f(_obj):
    _start = time.time()
    _df = _obj.details.copy()
    _df['type'] = ['SA' if (('SA' in _t) or ('BSL' in _t)) else 'ND' if ('ND' in _t) else 'unclassfied' for _t in _df.experiment_type]
    for _name in _obj.sessions.keys():
        _behavior     = _obj.sessions[_name].behavior
        _fiber        = _obj.sessions[_name].fiber
        _session      = _obj.sessions[_name]
############################# BEHAVIOR #######################################################################################
        ND1           = ', '.join([str(i) for i in _behavior.ND_1])       if 'ND_1' in _behavior.__dict__ else 'no ND1'
        ND2           = ', '.join([str(i) for i in _behavior.ND_2])       if 'ND_2' in _behavior.__dict__ else 'no ND2'
        D1            = ', '.join([str(i) for i in _behavior.D_1])
        D2            = ', '.join([str(i) for i in _behavior.D_2])        if 'D_2' in _behavior.__dict__ else 'no D2'
        _np1_ND1      = _behavior.timestamps('np1','ND_1')                if 'ND_1' in _behavior.__dict__ else np.array([])
        _np2_ND1      = _behavior.timestamps('np2','ND_1')                if 'ND_1' in _behavior.__dict__ else np.array([])
        _npT_ND1      = np.sort(np.concatenate((_np1_ND1,_np2_ND1)))      if 'ND_1' in _behavior.__dict__ else np.array([])
        _np1_ND2      = _behavior.timestamps('np1','ND_2')                if 'ND_2' in _behavior.__dict__ else np.array([])
        _np2_ND2      = _behavior.timestamps('np2','ND_2')                if 'ND_2' in _behavior.__dict__ else np.array([])
        _npT_ND2      = np.sort(np.concatenate((_np1_ND2,_np2_ND2)))      if 'ND_2' in _behavior.__dict__ else np.array([])
        _np1_D1       = _behavior.timestamps('np1','D_1')
        _np2_D1       = _behavior.timestamps('np2','D_1')
        _npT_D1       = np.sort(np.concatenate((_np1_D1,_np2_D1)))
        _np1_D2       = _behavior.timestamps('np1','D_2')                 if 'D_2' in _behavior.__dict__ else np.array([])
        _np2_D2       = _behavior.timestamps('np2','D_2')                 if 'D_2' in _behavior.__dict__ else np.array([])
        _npT_D2       = np.sort(np.concatenate((_np1_D2,_np2_D2)))        if 'D_2' in _behavior.__dict__ else np.array([])

        _inj_D1       = _behavior.timestamps('inj1','D_1')
        _inj_D2       = _behavior.timestamps('inj1','D_2')                if 'D_2' in _behavior.__dict__ else np.array([])

        np1_T         = _behavior.np1.shape[0]
        np2_T         = _behavior.np2.shape[0]
        np_T          = np1_T + np2_T
        inj_T         = _behavior.inj1.shape[0]  

        np1_ND1       = _np1_ND1.shape[0]                                 if 'ND_1' in _behavior.__dict__ else np.nan
        np1_ND2       = _np1_ND2.shape[0]                                 if 'ND_2' in _behavior.__dict__ else np.nan
        np2_ND1       = _np2_ND1.shape[0]                                 if 'ND_1' in _behavior.__dict__ else np.nan
        np2_ND2       = _np2_ND2.shape[0]
        npT_ND1       = _npT_ND1.shape[0]                                 if 'ND_1' in _behavior.__dict__ else np.nan
        npT_ND2       = _npT_ND2.shape[0]
        np1_1min_ND1  = _behavior.timestamps('np1','ND_1',60).shape[0]    if 'ND_1' in _behavior.__dict__ else np.nan
        np2_1min_ND1  = _behavior.timestamps('np2','ND_1',60).shape[0]    if 'ND_1' in _behavior.__dict__ else np.nan
        npT_1min_ND1  = np1_1min_ND1 + np2_1min_ND1
        inj_D1        = _behavior.timestamps('inj1','D_1').shape[0]
        inj_D2        = _behavior.timestamps('inj1','D_2').shape[0]        if 'D_2' in _behavior.__dict__ else np.nan
        D1_start      = _behavior.D_1[0][0]
        D2_start      = _behavior.D_2[0][0]                                if 'D_2' in _behavior.__dict__ else np.nan
        ND1_start     = _behavior.ND_1[0][0]                               if 'ND_1' in _behavior.__dict__ else np.nan
        ND2_start     = _behavior.ND_2[0][0]                               if 'ND_2' in _behavior.__dict__ else np.nan
        np1_D1_lat    = round(_np1_D1[0]  - D1_start ,3)  if len(_np1_D1) else np.nan
        np2_D1_lat    = round(_np2_D1[0]  - D1_start ,3)  if len(_np2_D1) else np.nan
        npT_D1_lat    = round(_npT_D1[0]  - D1_start ,3)  if len(_npT_D1) else np.nan
        D2_np1_lat    = round(_np1_D2[0]  - D2_start ,3)  if len(_np1_D2) else np.nan
        D2_np2_lat    = round(_np2_D2[0]  - D2_start ,3)  if len(_np2_D2) else np.nan
        D2_npT_lat    = round(_npT_D2[0]  - D2_start ,3)  if len(_npT_D2) else np.nan
        np1_ND1_lat   = round(_np1_ND1[0] - ND1_start,3)  if len(_np1_ND1) else np.nan
        np2_ND1_lat   = round(_np2_ND1[0] - ND1_start,3)  if len(_np2_ND1) else np.nan
        npT_ND1_lat   = round(_npT_ND1[0] - ND1_start,3)  if len(_npT_ND1) else np.nan
        np1_ND2_lat   = round(_np1_ND2[0] - ND2_start,3)  if len(_np1_ND2) else np.nan                     
        np2_ND2_lat   = round(_np2_ND2[0] - ND2_start,3)  if len(_np2_ND2) else np.nan                         
        npT_ND2_lat   = round(_npT_ND2[0] - ND2_start,3)  if len(_npT_ND2) else np.nan                          
        inj_D1_lat    = round(_inj_D1[0]  - D1_start ,3)  if len(_inj_D1) else np.nan
        inj_D2_lat    = round(_inj_D2[0]  - D2_start ,3)  if len(_inj_D2) else np.nan
        F6_1          = _behavior.timestamps('np1','ND_1',60*6).shape[0]    if 'ND_1' in _behavior.__dict__ else np.nan
        L9_1          = np1_ND1 - F6_1                                      if 'ND_1' in _behavior.__dict__ else np.nan
        L9F6diff_1    = L9_1 - F6_1                                         if 'ND_1' in _behavior.__dict__ else np.nan
        if np1_ND1:
            L9F6ratio_1   = round(L9F6diff_1/np1_ND1,3)
        else:
            L9F6ratio_1   = np.nan
        late_seeker_1 = 1 if (L9F6diff_1 >= 50)&(L9F6ratio_1 >= 0.5) else 0
        F6_2          = _behavior.timestamps('np1','ND_2',60*6).shape[0]     if 'ND_2' in _behavior.__dict__ else np.nan
        L9_2          = np1_ND2 - F6_2                                       if 'ND_2' in _behavior.__dict__ else np.nan
        L9F6diff_2    = L9_2 - F6_2                                          if 'ND_2' in _behavior.__dict__ else np.nan
        if np1_ND2 and ('ND_2' in _behavior.__dict__):
            L9F6ratio_2   = round(L9F6diff_2/np1_ND2,3)               
        else: 
            L9F6ratio_2   = np.nan
        late_seeker_2 = 1 if (L9F6diff_2 >= 50)&(L9F6ratio_2 >= 0.5) else 0
####################################################################################################################        
        # switch dkD1
        print(_name)
        dk_D1_time      = _behavior.LED2_ON[0][0] 
        
        _peakdk_D1pre       = _fiber.peakFA(dk_D1_time-10,dk_D1_time)
        dk_D1_peakFpre      = _peakdk_D1pre['frequency']  if _peakdk_D1pre else None  
        dk_D1_peakAdFpre    = _peakdk_D1pre['mean dF/F']   if _peakdk_D1pre else None  
        dk_D1_peakAZpre     = _peakdk_D1pre['mean zscore'] if _peakdk_D1pre else None 
        
        _peakdk_D1post      = _fiber.peakFA(dk_D1_time,dk_D1_time+10)
        dk_D1_peakFpost     = _peakdk_D1post['frequency']  if _peakdk_D1post else None    
        dk_D1_peakAdFpost   = _peakdk_D1post['mean dF/F']   if _peakdk_D1post else None
        dk_D1_peakAZpost    = _peakdk_D1post['mean zscore'] if _peakdk_D1post else None
        
        dk_D1_peakFpostpreR   = dk_D1_peakFpost  /dk_D1_peakFpre   if (dk_D1_peakFpost   != None) and dk_D1_peakFpre   else None
        dk_D1_peakAdFpostpreR = dk_D1_peakAdFpost/dk_D1_peakAdFpre if (dk_D1_peakAdFpost != None) and dk_D1_peakAdFpre else None
        dk_D1_peakAZpostpreR  = dk_D1_peakAZpost /dk_D1_peakAdFpre if (dk_D1_peakAZpost  != None) and dk_D1_peakAZpre  else None 
        
        _r1_dk_D1    = _session.analyze_perievent(dk_D1_time,window=(1,1))
        _r3_dk_D1    = _session.analyze_perievent(dk_D1_time,window=(3,3))
        _r5_dk_D1    = _session.analyze_perievent(dk_D1_time,window=(5,5))
        
        dk_D1_1preavgZ    = _r1_dk_D1.preAVG_Z   if _r1_dk_D1 else None
        dk_D1_1postavgZ   = _r1_dk_D1.postAVG_Z  if _r1_dk_D1 else None
        dk_D1_1preAUCdF   = _r1_dk_D1.preAUC     if _r1_dk_D1 else None
        dk_D1_1postAUCdF  = _r1_dk_D1.postAUC    if _r1_dk_D1 else None
        dk_D1_3preavgZ    = _r3_dk_D1.preAVG_Z   if _r3_dk_D1 else None
        dk_D1_3postavgZ   = _r3_dk_D1.postAVG_Z  if _r3_dk_D1 else None 
        dk_D1_3preAUCdF   = _r3_dk_D1.preAUC     if _r3_dk_D1 else None
        dk_D1_3postAUCdF  = _r3_dk_D1.postAUC    if _r3_dk_D1 else None
        dk_D1_5preavgZ    = _r5_dk_D1.preAVG_Z   if _r5_dk_D1 else None
        dk_D1_5postavgZ   = _r5_dk_D1.postAVG_Z  if _r5_dk_D1 else None
        dk_D1_5preAUCdF   = _r5_dk_D1.preAUC     if _r5_dk_D1 else None
        dk_D1_5postAUCdf  = _r5_dk_D1.postAUC    if _r5_dk_D1 else None
        
        #switch D1_ND1
        D1_ND1_time      = _behavior.switch_1[0]     if _behavior.switch_1 else None
        
        _peakD1_ND1pre      = _fiber.peakFA(D1_ND1_time-10,D1_ND1_time)  if _behavior.switch_1 else None
        D1_ND1_peakFpre      = _peakD1_ND1pre['frequency']  if _peakD1_ND1pre else None
        D1_ND1_peakAdFpre    = _peakD1_ND1pre['mean dF/F']   if _peakD1_ND1pre else None
        D1_ND1_peakAZpre     = _peakD1_ND1pre['mean zscore'] if _peakD1_ND1pre else None
        
        _peakD1_ND1post      = _fiber.peakFA(D1_ND1_time,D1_ND1_time+10)  if _behavior.switch_1 else None
        D1_ND1_peakFpost     = _peakD1_ND1post['frequency']  if _peakD1_ND1post else None
        D1_ND1_peakAdFpost   = _peakD1_ND1post['mean dF/F']   if _peakD1_ND1post else None
        D1_ND1_peakAZpost    = _peakD1_ND1post['mean zscore'] if _peakD1_ND1post else None
        
        D1_ND1_peakFpostpreR   = D1_ND1_peakFpost  /D1_ND1_peakFpre   if (D1_ND1_peakFpost   != None) and D1_ND1_peakFpre   else None 
        D1_ND1_peakAdFpostpreR = D1_ND1_peakAdFpost/D1_ND1_peakAdFpre if (D1_ND1_peakAdFpost != None) and D1_ND1_peakAdFpre else None
        D1_ND1_peakAZpostpreR  = D1_ND1_peakAZpost /D1_ND1_peakAdFpre if (D1_ND1_peakAZpost  != None) and D1_ND1_peakAZpre  else None 
        
        _r1_D1_ND1   = _session.analyze_perievent(D1_ND1_time,window=(1,1)) if _behavior.switch_1 else None
        _r3_D1_ND1   = _session.analyze_perievent(D1_ND1_time,window=(3,3)) if _behavior.switch_1 else None
        _r5_D1_ND1   = _session.analyze_perievent(D1_ND1_time,window=(5,5)) if _behavior.switch_1 else None
        
        D1_ND1_1preavgZ    = _r1_D1_ND1.preAVG_Z   if _r1_D1_ND1 else None
        D1_ND1_1postavgZ   = _r1_D1_ND1.postAVG_Z  if _r1_D1_ND1 else None
        D1_ND1_1preAUCdF   = _r1_D1_ND1.preAUC     if _r1_D1_ND1 else None
        D1_ND1_1postAUCdF  = _r1_D1_ND1.postAUC    if _r1_D1_ND1 else None
        D1_ND1_3preavgZ    = _r3_D1_ND1.preAVG_Z   if _r3_D1_ND1 else None
        D1_ND1_3postavgZ   = _r3_D1_ND1.postAVG_Z  if _r3_D1_ND1 else None
        D1_ND1_3preAUCdF   = _r3_D1_ND1.preAUC     if _r3_D1_ND1 else None
        D1_ND1_3postAUCdF  = _r3_D1_ND1.postAUC    if _r3_D1_ND1 else None
        D1_ND1_5preavgZ    = _r5_D1_ND1.preAVG_Z   if _r5_D1_ND1 else None
        D1_ND1_5postavgZ   = _r5_D1_ND1.postAVG_Z  if _r5_D1_ND1 else None
        D1_ND1_5preAUCdf   = _r5_D1_ND1.preAUC     if _r5_D1_ND1 else None
        D1_ND1_5postAUCdf  = _r5_D1_ND1.postAUC    if _r5_D1_ND1 else None
        
        # switch ND1_D2
        _list = [_b for _a,_b in _behavior.HLED_ON if D1_ND1_time == _a]
        ND1_D2_time       = _list[0] if _list else None
        
        _peakND1_D2pre       = _fiber.peakFA(ND1_D2_time-10,ND1_D2_time)  if _list else None 
        ND1_D2_peakFpre      = _peakND1_D2pre['frequency']  if _peakND1_D2pre else None
        ND1_D2_peakAdFpre    = _peakND1_D2pre['mean dF/F']   if _peakND1_D2pre else None
        ND1_D2_peakAZpre     = _peakND1_D2pre['mean zscore'] if _peakND1_D2pre else None
        
        _peakND1_D2post       = _fiber.peakFA(ND1_D2_time,ND1_D2_time+10)  if _list else None 
        ND1_D2_peakFpost      = _peakND1_D2post['frequency']  if _peakND1_D2post else None
        ND1_D2_peakAdFpost    = _peakND1_D2post['mean dF/F']   if _peakND1_D2post else None
        ND1_D2_peakAZpost     = _peakND1_D2post['mean zscore'] if _peakND1_D2post else None
        
        _r1_ND1_D2   = _session.analyze_perievent(ND1_D2_time,window=(1,1)) if _list else None
        _r3_ND1_D2   = _session.analyze_perievent(ND1_D2_time,window=(3,3)) if _list else None
        _r5_ND1_D2   = _session.analyze_perievent(ND1_D2_time,window=(5,5)) if _list else None
        
        ND1_D2_peakFpostpreR   = ND1_D2_peakFpost  /ND1_D2_peakFpre   if (ND1_D2_peakFpost   != None) and ND1_D2_peakFpre else None
        ND1_D2_peakAdFpostpreR = ND1_D2_peakAdFpost/ND1_D2_peakAdFpre if (ND1_D2_peakAdFpost != None) and ND1_D2_peakAdFpre else None
        ND1_D2_peakAZpostpreR  = ND1_D2_peakAZpost /ND1_D2_peakAdFpre if (ND1_D2_peakAZpost  != None) and ND1_D2_peakAZpre else None
        
        ND1_D2_1preavgZ    = _r1_ND1_D2.preAVG_Z   if _r1_ND1_D2 else None
        ND1_D2_1postavgZ   = _r1_ND1_D2.postAVG_Z  if _r1_ND1_D2 else None
        ND1_D2_1preAUCdF   = _r1_ND1_D2.preAUC     if _r1_ND1_D2 else None
        ND1_D2_1postAUCdF  = _r1_ND1_D2.postAUC    if _r1_ND1_D2 else None
        ND1_D2_3preavgZ    = _r3_ND1_D2.preAVG_Z   if _r3_ND1_D2 else None
        ND1_D2_3postavgZ   = _r3_ND1_D2.postAVG_Z  if _r3_ND1_D2 else None
        ND1_D2_3preAUCdF   = _r3_ND1_D2.preAUC     if _r3_ND1_D2 else None
        ND1_D2_3postAUCdF  = _r3_ND1_D2.postAUC    if _r3_ND1_D2 else None
        ND1_D2_5preavgZ    = _r5_ND1_D2.preAVG_Z   if _r5_ND1_D2 else None 
        ND1_D2_5postavgZ   = _r5_ND1_D2.postAVG_Z  if _r5_ND1_D2 else None 
        ND1_D2_5preAUCdf   = _r5_ND1_D2.preAUC     if _r5_ND1_D2 else None 
        ND1_D2_5postAUCdf  = _r5_ND1_D2.postAUC    if _r5_ND1_D2 else None 
####################################################################################################################
        _data = vars()
        _data = {_k:_v for _k,_v in _data.items() if _k[0] != '_'}
        for _k,_v in _data.items():
            if _k not in _df.columns:
                _df[_k] = pd.Series([np.nan])
            _idx = _df[_df.session == _name].index
            _df.loc[_idx,_k] = _v
    _df.to_csv('FIBER_BEHAVIOR_ALL.csv',sep=';')
    print(f"Extraction took {time.time() - _start} seconds")
    return _df

# %%
s.plot('signal')

# %%
df = f(s)

# %%
df.to_pickle('FIBER.pickle')

# %% [markdown]
# **Correlation between normalized D1-ND1 DS switch Z-score/ Df/f and total ND1 nosepokes**
# + 1s, 3s, 5s
# total ND1 ======= ok
# ND1_switch ====== ok
#
# **Correlation between normalized D1-ND1 DS switch Z-score/ Df/f and 1 min ND1 nosepokes**
# + 1s, 3s, 5s
# 1min ND1 NP ===== ok
#
# **Correlation between normalized D1-ND1 DS switch Z-score/ Df/f and latency to first ND nosepoke**
# + 1s, 3s, 5s
# latency to first ND ==== ok with user output abs(timestamps('switch_1')[0] - ND_1[0][0])
#
# **Correlation between normalized D1-ND1 DS switch Z-score/ Df/f and inj in previous D period- controlling that the recruitment does not depend on how much cocaine is in the system**
# + 1s, 3s, 5s
# injection during previous D period ===== timestamps('inj1','D_1')
#
# **Split rats into high/low based on ND1 median split**
# + Peak amplitude/frequency differences D / ND
# ND1 median split ======== len('np1','ND_1')/median avg by session ?
#
# **Correlation between normalized -D1 DS switch Z-score/ Df/f and latency to first D nosepoke**
# + 1s, 3s, 5s
# -DS switch ============= start of first D?
# latency to first ========== shoudl be easy
#
# **Correlation between normalized -D1 DS switch Z-score/ Df/f and latency to first injection**
# + 1s, 3s, 5s
#
# **Correlation between normalized -D1 DS switch Z-score/ Df/f and number of injections in D1**
# + 1s, 3s, 5s
# === number of injections in D1
#
# **Correlation between normalized -D1 DS switch Z-score/ Df/f and latency to first D2 nosepoke**
# + 1s, 3s, 5s
# ===== latency to first D2 nosepoke (might be some np.nan)
#
# **Correlation between normalized -D1 DS switch Z-score/ Df/f and latency to first injection D2**
# + 1s, 3s, 5s
# ===== latency to first D2 injection (might be some np.nan)
#
# **Correlation between normalized -D1 DS switch Z-score/ Df/f and number of injections in D1**
# + 1s, 3s, 5s

# %%
d = df.copy()

# %%
from scipy import stats

# %%
dic = {}
count = 0
for i in d.columns:
    if (d[i].dtype == 'float64') and ('time' not in i) and ('_start' not in i)  and (i[-3:] != 'pre') and (i[-4:] != 'post'):
        if ('peak' in i) or ('post' in i) or ('pre' in i):
            ti = 'fiber'
        else:
            ti = 'behavior'
        for j in d.columns:
            if (i != j) and ('time' not in j) and ('_start' not in j) and (j[-3:] != 'pre') and (j[-4:] != 'post'):
                if d[j].dtype == 'float64':
                    if ('peak' in j) or ('post' in j) or ('pre' in j):
                        tj = 'fiber'
                    else:
                        tj = 'behavior'
                    if tj != ti:
                        newdf = d[[i,j]]
                        newdf.dropna(axis=0,inplace=True)
                        if len(newdf.columns) == 2 and len(newdf) >2:
                            if not f'{j} --- {i}' in dic.keys():
                                print(i,j)
                                count += 1
                                print(count)
                                p,r = stats.pearsonr(newdf[i],newdf[j])
                                dic[f'{i} --- {j}'] = [i,j,p,r,len(newdf)]

# %%
len(dic)

# %%
res = pd.DataFrame(dic,index=['a','b','r','p','n']).T
res['r2'] = np.power(res.r,2)
res['sorter'] = [np.round(i) for i in 10*res['r2'].to_numpy()]

# %%
res = res[(res.p<0.05) & (res.n >20)].sort_values(['sorter','a','b'],ascending=False)
res.reset_index(inplace=True,drop=True)
res.to_csv('corr.csv',sep=';')

# %%
dg = pd.read_pickle('FIBER.pickle')

# %%
a  = [i for i in dg.columns if 'lat' in i]

# %%
a = ['np1_ND2_lat',
'npT_ND1_lat',
'npT_ND1_lat','ND1_D2_peakFpostpreR',
'D1_ND1_5postavgZ',
'D1_ND1_3postavgZ']

# %%
d.corr().loc['npT_ND1_lat','D1_ND1_5postavgZ']

# %%
tuples = [[(a,b) for a in d.corr()] for b in d.corr().columns]
tuples = [a for i in tuples for a in i]
tuples = [(a,b) for a,b in tuples if a != b]
tuples = [(a,b) for a,b in tuples if d.corr().loc[a,b] > 0.4]

# %%
tuples = [(a,b) for a,b in tuples if ('1pre' not in a)  and ('1pre' not in b)  and ('3pre' not in a)  and ('3pre' not in b) and\
 ('1post' not in a) and ('1post' not in b) and ('3post' not in a) and ('3post' not in b)]

# %%
tuples = [(a,b) for a,b in tuples if not( (('peak' in a) or ('pre' in a) or ('post' in a)) \
                                       &  (('peak' in b) or ('pre' in b) or ('post' in b)) )]

# %%
tuples = [(a,b) for a,b in tuples if not( (('peak' not in a) and ('pre' not in a) and ('post' not in a)) \
                                       &  (('peak' not in b) and ('pre' not in b) and ('post' not in b)) )]

# %%
d = d[d.ID != 'AS21R_3']

# %%
d['shortID'] = [i[1]+i.split('_')[-1] for i in d.ID.to_list()]

fig,ax = plt.subplots(len(tuples),figsize=(10,5*len(tuples)))

for n,(newX,newY) in enumerate(tuples):
    lat = d[[newX,newY,'shortID']].copy()
    lat.dropna(inplace=True)
    ax[n].scatter(lat[newX],lat[newY])
    sns.regplot(x=newX,y=newY, data=lat, ax=ax[n])

# %%
plt.style.use('bmh')
lat = d[['experiment', 'rat_number', 'experiment_type', 'session_number', 'ID','ND1','D1',
       'session', 'type','session','D1_ND1_time','npT_ND1_lat','D1_ND1_5postavgZ']].copy()
newX = 'Latency to first ND1 nosepoke since the Ds shift (s)'
newY = 'Average Z-score post (5s) DS shift'

lat['shortID'] = [i[1]+i.split('_')[-1] for i in d.ID]
lat[newX] = lat.npT_ND1_lat.to_numpy()
lat[newY] = lat.D1_ND1_5postavgZ.to_numpy()
lat.dropna(inplace=True)
lat = lat[lat.ID != 'AS21R_3']
lat.reset_index(drop=True,inplace=True)
lat.index = lat.ID.to_list()

ax = lat.plot(x=newX,y=newY,legend=True,kind='scatter',s=10,figsize=(20,15))
ax = lat[[newX,newY,'shortID']].apply(lambda x: ax.text(*x,c='k'),axis=1)
ax = sns.regplot(x=newX,y=newY, data=lat)
plt.title('by session')

# %%
ind = lat.copy()

# %%
di = pd.DataFrame({'Latency to first ND1 nosepoke since the Ds shift (s)':pd.Series([]),
       'Average Z-score post (5s) DS shift':pd.Series([])},index=list(set(ind.shortID.to_list())))
for r in di.index:
    dtemp = ind[ind.shortID == r]
    for c in di.columns:
        di.loc[r,c] = dtemp[c].to_numpy().mean()

# %%
di['shortID'] = di.index.to_list()

# %%
ax = di.plot(x=newX,y=newY,legend=True,kind='scatter',s=10,figsize=(20,15))
ax = di[[newX,newY,'shortID']].apply(lambda x: ax.text(*x,c='k'),axis=1)
ax = sns.regplot(x=newX,y=newY, data=di)
plt.title('by subject')

# %%
di.corr()

# %%
len(di)

# %%
sorted(di.shortID.to_list())
