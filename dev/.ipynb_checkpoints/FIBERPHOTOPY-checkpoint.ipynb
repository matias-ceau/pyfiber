# %%
# %cd ../fiberphotopy/
# Out:
# C:\Users\mceau\Documents\fiberphotopy\fiberphotopy

# %%
import importlib
import numpy as np
import pandas as pd
import yaml
import matplotlib.pyplot as plt
import pprint
import scipy
import time


import fp_utils
import behavioral_data
import fiber_data
import analysis

def rel():
    importlib.reload(behavioral_data)
    importlib.reload(fiber_data)
    importlib.reload(analysis)
    importlib.reload(fp_utils)
rel()

# %% [markdown]
# # Brouillons

# %%
# %ls
# Out:
#  Le volume dans le lecteur C s’appelle System
#  Le numéro de série du volume est A698-0041
#
#  Répertoire de C:\Users\mceau\Documents\fiberphotopy\fiberphotopy
#
# 17/03/2022  13:21    <DIR>          .
# 17/03/2022  13:21    <DIR>          ..
# 16/03/2022  17:03    <DIR>          .ipynb_checkpoints
# 16/03/2022  15:08                 0 __init__.py
# 17/03/2022  13:21    <DIR>          __pycache__
# 16/03/2022  15:59             9 610 analysis.py
# 17/03/2022  13:21            21 944 behavioral_data.py
# 16/03/2022  15:59             8 830 fiber_data.py
# 16/03/2022  17:03             1 397 fp_utils.py
# 11/03/2022  10:49             6 929 info.py
#                6 fichier(s)           48 710 octets
#                4 Rép(s)  915 446 509 568 octets libres

# %%
b = behavioral_data.BehavioralData('../../DATA/Habituation1j1603202201rat25.dat')

# %%
p08.__dict__
# Out:
# {'hello': 'Hi',
#  'configfile': 'config.yaml',
#  'config': {'USER': {'GENERAL': {'rat_ID': 'Not specified',
#     'file_unit': False,
#     'user_unit': 's',
#     'experiment_duration': {'min': 29, 'max': 28999}},
#    'BEHAVIOR': {'fixed_ratio': 5,
#     'close_interval': 5,
#     'elements': {'HLED_OFF': [True, 'Drug Period', '#069AF3'],
#      'HLED_ON': [True, 'No Drug Period', 'gold'],
#      'TTL1_ON': [True, 'Fiber Photometry Recordings', 'g'],
#      'np1': [True, 'Active Nosepokes', 'r'],
#      'np2': [True, 'Inactive Nosepokes', 'b'],
#      'inj1': [True, 'Injections', 'k'],
#      'LED1_ON': [True, 'Conditioned Stimulus', 'goldenrod'],
#      'LED1_OFF': [False, 'LED1_OFF', ['darkgray', 'darkgrey']],
#      'LED2_OFF': [False, 'LED2_OFF', 'slategrey'],
#      'LED2_ON': [True, ' Drug Light On', 'slategrey'],
#      'DARK': [False, 'DARK', 'k'],
#      'TO_DARK': [False, 'TO_DARK', 'olivedrab'],
#      'NOTO_DARK': [False, 'NOTO_DARK', 'black'],
#      'TIMEOUT': [True, 'Time outs', 'k'],
#      'switch_d_nd': [False, 'Switch from D to ND', 'r'],
#      'switch_to_nd': [False, 'Switch from TO to ND', 'r'],
#      'switch_nd_d': [False, 'Switch from ND to D', 'b']}},
#    'FIBERPHOTOMETRY': {'split_recordings': True,
#     'split_treshold': 10,
#     'trim_recording': 2.0,
#     'default_window': [10.0, 10.0],
#     'self.default_norm': 'F'}},
#   'IMETRONIC': {'LIGHTS': {'HLED': [1, 1],
#     'LED1': [1, 2],
#     'LED2': [1, 3],
#     'LED3': [1, 4],
#     'LED4': [1, 5],
#     'LED5': [1, 6],
#     'LED6': [1, 7],
#     'LED7': [1, 8]},
#    'LEVERS': {'L1': [2, 1],
#     'L2': [2, 2],
#     'L3': [2, 3],
#     'L4': [2, 4],
#     'L5': [2, 5],
#     'L6': [2, 6]},
#    'NOSEPOKE': {'NP1': [3, 1],
#     'NP2': [3, 2],
#     'NP3': [3, 3],
#     'NP4': [3, 4],
#     'NP5': [3, 5]},
#    'DISTRIBUTEUR': {'D1': [4, 1],
#     'D2': [4, 2],
#     'D3': [4, 3],
#     'D4': [4, 4],
#     'D5': [4, 5],
#     'D6': [4, 6],
#     'D7': [4, 7],
#     'D8': [4, 8],
#     'D9': [4, 9],
#     'D10': [4, 10],
#     'D11': [4, 11],
#     'D12': [4, 12]},
#    'LICKMETER': {'LK1': [5, 1],
#     'LK2': [5, 2],
#     'LK3': [5, 3],
#     'LK4': [5, 4],
#     'LK5': [5, 5]},
#    'DIVERS_CA': {'INJ1': [6, 1],
#     'SND': [6, 2],
#     'WN': [6, 3],
#     'SHK': [6, 4],
#     'PUSH': [6, 5],
#     'TOP': [6, 6],
#     'INJ2': [6, 7],
#     'ADC': [6, 8],
#     'SNDpP': [6, 9],
#     'FL': [6, 10],
#     'RD': [6, 11],
#     'OD': [6, 12],
#     'BUL': [6, 13],
#     'WH': [6, 14]},
#    'PORTE': {'G1': [7, 1],
#     'G2': [7, 2],
#     'G3': [7, 3],
#     'G4': [7, 4],
#     'G5': [7, 5],
#     'G6': [7, 6],
#     'G7': [7, 7],
#     'G8': [7, 8],
#     'G9': [7, 9],
#     'G10': [7, 10],
#     'G11': [7, 11],
#     'G12': [7, 12]},
#    'ZONE': {'Z1': [9, 1],
#     'Z2': [9, 2],
#     'Z3': [9, 3],
#     'Z4': [9, 4],
#     'Z5': [9, 5],
#     'Z6': [9, 6],
#     'Z7': [9, 7],
#     'Z8': [9, 8],
#     'Z9': [9, 9],
#     'Z10': [9, 10],
#     'Z11': [9, 11],
#     'Z12': [9, 12],
#     'Z13': [9, 13]},
#    'DIVERS': {'ON': [10, 1], 'EVT': [10, 5]},
#    'RFID': {'I1': [12, 1], 'I2': [12, 2], 'I3': [12, 3], 'I4': [12, 4]},
#    'MESSAGE': {'STR1': [13, 1],
#     'STR2': [13, 2],
#     'STR3': [13, 3],
#     'STR4': [13, 4]},
#    'DIVERS_NON_STOCKES': {'I': [11, 4]}},
#   'DORIC': {'Time(s)': 'time',
#    'AIn-1 - Demodulated(Lock-In)': 'signal',
#    'AIn-2 - Demodulated(Lock-In)': 'control',
#    'DI/O-1': 'TTL1',
#    'DI/O-2': 'TTL2',
#    'DI/O-3': 'TTL3',
#    'DI/O-4': 'TTL4'}},
#  'rat_ID': None,
#  'file_unit': False,
#  'user_unit': 's',
#  'experiment_duration': {'min': 29, 'max': 28999},
#  'fixed_ratio': 5,
#  'close_interval': 5,
#  'elements': {'HLED_OFF': [True, 'Drug Period', '#069AF3'],
#   'HLED_ON': [True, 'No Drug Period', 'gold'],
#   'TTL1_ON': [True, 'Fiber Photometry Recordings', 'g'],
#   'np1': [True, 'Active Nosepokes', 'r'],
#   'np2': [True, 'Inactive Nosepokes', 'b'],
#   'inj1': [True, 'Injections', 'k'],
#   'LED1_ON': [True, 'Conditioned Stimulus', 'goldenrod'],
#   'LED1_OFF': [False, 'LED1_OFF', ['darkgray', 'darkgrey']],
#   'LED2_OFF': [False, 'LED2_OFF', 'slategrey'],
#   'LED2_ON': [True, ' Drug Light On', 'slategrey'],
#   'DARK': [False, 'DARK', 'k'],
#   'TO_DARK': [False, 'TO_DARK', 'olivedrab'],
#   'NOTO_DARK': [False, 'NOTO_DARK', 'black'],
#   'TIMEOUT': [True, 'Time outs', 'k'],
#   'switch_d_nd': [False, 'Switch from D to ND', 'r'],
#   'switch_to_nd': [False, 'Switch from TO to ND', 'r'],
#   'switch_nd_d': [False, 'Switch from ND to D', 'b']},
#  'split_recordings': True,
#  'split_treshold': 10,
#  'trim_recording': 2.0,
#  'default_window': [10.0, 10.0],
#  'self.default_norm': 'F',
#  'behavior': GENERAL INFORMATION:
#  ******************************************************************************************************************************************************************
#      Filename            : poster_data/bsa08032022c20_01.dat
#      Rat ID              : Not specified
#      Experiment duration : 9000.112 (s)
#      Time unit           : s (File original unit: ms
#      Fixed ratio         : FR5
#
#  Useful commands:
#      - <obj>.summary() : shows graphical summary of the dat file
#      - <obj>.df        : shows raw IMETRONIC data
#      - <obj>.elements  : list of elements that can be used in the main functions
#
#  Main functions:
#      - <obj>.timestamps(param)  : outputs timestamps based on user-defined criteria and optionally outputs a csv of timestamps
#      - <obj>._internal_graph(element)     : shows graphical representation of the element
#      - <obj>.get(param)         : outputs slice from full dat file (formatted as a DataFrame)
#
#  FULL_HELP: <obj>.info,
#  'fiber': File                 : poster_data/modAS21RSA3Rat1208032022_0.csv
#  Rat_ID               : None
#  Number of recordings : 4
#  Data columns         : ['time', 'signal', 'control', 'TTL1', 'TTL2', 'TTL3', 'TTL4']
#  Total lenght         : 3540.032488553392 s
#  Kept lenght          : 3540.032488553392 (0.0 seconds trimmed)
#  Global sampling rate : 1209.043646919061 S/s
#  Original file unit   : s,
#  'analyses': {},
#  'analyzable_events': {'hled_on': array([2400.003, 5700.01 ]),
#   'hled_off': array([3300.007]),
#   'led1_on': array([  83.873,  164.267, 3315.23 , 3408.029, 4359.558, 5681.91 ]),
#   'led1_off': array([  87.872,  168.267, 2400.003, 3319.23 , 4363.558, 5685.91 ,
#          5700.01 ]),
#   'led2_on': array([ 127.872, 3300.007, 3359.23 , 4403.561]),
#   'led2_off': array([  87.872,  168.267, 2400.003, 3319.23 , 4363.558, 5685.91 ,
#          5700.01 ]),
#   'np1': array([  50.864,   72.89 ,   77.811,   82.927,   83.872,  143.499,
#           144.024,  159.059,  159.497,  164.267, 3305.904, 3311.951,
#          3312.294, 3312.66 , 3315.23 , 3404.907, 3405.225, 3407.18 ,
#          3407.554, 3408.029, 4357.659, 4357.871, 4358.51 , 4359.282,
#          4359.558, 5649.811, 5650.666, 5651.049, 5681.214, 5681.91 ]),
#   'np2': array([44.452, 45.062]),
#   'inj1': array([  85.224,  165.619, 3316.582, 3409.38 , 4360.909, 5683.261]),
#   'ttl1_on': array([], dtype=float64),
#   'ttl1_off': array([], dtype=float64),
#   'rec_start': array([], dtype=float64),
#   'switch_d_nd': array([2400.003]),
#   'switch_to_nd': array([5700.01]),
#   'switch_nd_d': array([3300.007]),
#   'np1_1': array([  50.864,  143.499, 3311.951, 3407.18 , 4357.659]),
#   'np1_2': array([  72.89 ,  144.024, 3312.294, 3407.554, 4357.871, 5649.811]),
#   'np1_3': array([  77.811,  159.059, 3312.66 , 4358.51 , 5650.666]),
#   'np1_4': array([  82.927,  159.497, 3404.907, 4359.282, 5651.049]),
#   'np1_5': array([  83.872, 3305.904, 3405.225, 5681.214])},
#  'recorded_intervals': {'HLED_ON': [(2400.003, 2510.004),
#    (3250.006, 3300.007),
#    (5700.01, 5810.01)],
#   'HLED_OFF': [(10.084, 180.004),
#    (2290.003, 2400.003),
#    (3300.007, 3410.011),
#    (4330.01, 4490.01),
#    (5590.01, 5700.01)],
#   'LED1_ON': [(83.873, 87.872),
#    (164.267, 168.267),
#    (3315.23, 3319.23),
#    (3408.029, 3410.011),
#    (4359.558, 4363.558),
#    (5681.91, 5685.91)],
#   'LED1_OFF': [(10.084, 83.873),
#    (87.872, 164.267),
#    (168.267, 180.004),
#    (2290.003, 2510.004),
#    (3250.006, 3315.23),
#    (3319.23, 3408.029),
#    (4330.01, 4359.558),
#    (4363.558, 4490.01),
#    (5590.01, 5681.91),
#    (5685.91, 5810.01)],
#   'LED2_ON': [(10.084, 87.872),
#    (127.872, 168.267),
#    (2290.003, 2400.003),
#    (3300.007, 3319.23),
#    (3359.23, 3410.011),
#    (4330.01, 4363.558),
#    (4403.561, 4490.01),
#    (5590.01, 5685.91)],
#   'LED2_OFF': [(87.872, 127.872),
#    (168.267, 180.004),
#    (2400.003, 2510.004),
#    (3250.006, 3300.007),
#    (3319.23, 3359.23),
#    (4363.558, 4403.561),
#    (5685.91, 5810.01)],
#   'TTL1_ON': [(10.084, 180.004),
#    (2290.003, 2510.004),
#    (3250.006, 3410.011),
#    (4330.01, 4490.01),
#    (5590.01, 5810.01)],
#   'TTL1_OFF': [],
#   'DARK': [(87.872, 127.872),
#    (168.267, 180.004),
#    (3319.23, 3359.23),
#    (4363.558, 4403.561),
#    (5685.91, 5700.01)],
#   'TO_DARK': [(87.872, 127.872),
#    (168.267, 180.004),
#    (3319.23, 3359.23),
#    (4363.558, 4403.561),
#    (5685.91, 5700.01)],
#   'TIMEOUT': [(83.873, 127.872),
#    (164.267, 180.004),
#    (3315.23, 3359.23),
#    (3408.029, 3410.011),
#    (4359.558, 4403.561),
#    (5681.91, 5700.01)],
#   'NOTO_DARK': [],
#   'D_1': [(10.084, 180.004), (2290.003, 2400.003)],
#   'D_2': [(3300.007, 3410.011), (4330.01, 4490.01), (5590.01, 5700.01)],
#   'D_3': [],
#   'ND_1': [(2400.003, 2510.004), (3250.006, 3300.007)],
#   'ND_2': [(5700.01, 5810.01)]}}

# %% [markdown]
# # Analysis

# %%
rel()
b1 = behavioral_data.BehavioralData('../../DATA/35/bsa09032022c20_02.dat')

# %%
# %ls
# Out:
#  Le volume dans le lecteur C s’appelle System
#  Le numéro de série du volume est A698-0041
#
#  Répertoire de C:\Users\mceau\Documents\fiberphotopy\fiberphotopy
#
# 21/03/2022  14:44    <DIR>          .
# 21/03/2022  14:44    <DIR>          ..
# 16/03/2022  17:03    <DIR>          .ipynb_checkpoints
# 16/03/2022  15:08                 0 __init__.py
# 21/03/2022  14:44    <DIR>          __pycache__
# 21/03/2022  14:44            11 185 analysis.py
# 21/03/2022  14:14            22 687 behavioral_data.py
# 21/03/2022  14:13               593 bsa09032022c20_02.csv
# 16/03/2022  15:59             8 830 fiber_data.py
# 16/03/2022  17:03             1 397 fp_utils.py
# 17/03/2022  14:11             6 965 info.py
#                7 fichier(s)           51 657 octets
#                4 Rép(s)  925 134 823 424 octets libres

# %%
os.listdir("../../DATA/test_data")
# Out:
# ['rat12_SA1', 'rat12_SA2', 'rat12_SA3']

# %%
rel()
test = analysis.MultiSession("../../DATA/test_data")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7128/4264674723.py in <module>
# ----> 1 rel()
#       2 test = analysis.MultiSession("../../DATA/test_data")
#
# ~\AppData\Local\Temp/ipykernel_7128/4051809663.py in rel()
#      17     importlib.reload(behavioral_data)
#      18     importlib.reload(fiber_data)
# ---> 19     importlib.reload(analysis)
#      20     importlib.reload(fp_utils)
#      21 rel()
#
# ~\Anaconda3\lib\importlib\__init__.py in reload(module)
#     138     """
#     139     if not module or not isinstance(module, types.ModuleType):
# --> 140         raise TypeError("reload() argument must be a module")
#     141     try:
#     142         name = module.__spec__.name
#
# TypeError: reload() argument must be a module

# %%
multi = test.analyze('np1',interval='HLED_OFF')
# Out:
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp
# No fiber recording at this timestamp

# %%
analysis
# Out:
# {'bsa01032022c20_02.dat': [<obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'bsa04032022c20_01.dat': [<obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC],
#  'modAS21RSA3Rat1208032022_0.csv': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   <obj>.event_time
#   <obj>.fiberfile
#   <obj>.behaviorfile
#   <obj>.normalisation
#   <obj>.rec_number
#   <obj>.window
#   <obj>.recordingdata
#   <obj>.rawdata
#   <obj>.data
#   <obj>.raw_signal
#   <obj>.raw_control
#   <obj>.signal
#   <obj>.time
#   <obj>.sampling_rate
#   <obj>.postevent
#   <obj>.pre_raw_sig
#   <obj>.post_raw_sig
#   <obj>.post_raw_ctrl
#   <obj>.post_time
#   <obj>.preevent
#   <obj>.pre_time
#   <obj>.zscores
#   <obj>.pre_zscores
#   <obj>.post_zscores
#   <obj>.rob_zscores
#   <obj>.pre_Rzscores
#   <obj>.post_Rzscores
#   <obj>.preAVG_Z
#   <obj>.postAVG_Z
#   <obj>.preAVG_RZ
#   <obj>.postAVG_RZ
#   <obj>.pre_raw_AUC
#   <obj>.post_raw_AUC
#   <obj>.preAUC
#   <obj>.postAUC
#   <obj>.preZ_AUC
#   <obj>.postZ_AUC
#   <obj>.preRZ_AUC
#   <obj>.postRZ_AUC,
#   None,
#   None,
#   None,
#   None,
#   None]}

# %%
for r in analysis.keys():
    for li in analysis[r]:
        if li != None:
            plt.figure(figsize=(10,5))
            plt.plot(li.time,li.zscores)
# Out:
# C:\Users\mceau\AppData\Local\Temp/ipykernel_7128/2974113184.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(10,5))

# %%
for obj in analysis['bsa01032022c20_02.dat']:
    if obj:
        for att in obj.__dict__.keys():
            print(att)
# Out:
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC
# event_time
# fiberfile
# behaviorfile
# normalisation
# rec_number
# window
# recordingdata
# rawdata
# data
# raw_signal
# raw_control
# signal
# time
# sampling_rate
# postevent
# pre_raw_sig
# post_raw_sig
# post_raw_ctrl
# post_time
# preevent
# pre_time
# zscores
# pre_zscores
# post_zscores
# rob_zscores
# pre_Rzscores
# post_Rzscores
# preAVG_Z
# postAVG_Z
# preAVG_RZ
# postAVG_RZ
# pre_raw_AUC
# post_raw_AUC
# preAUC
# postAUC
# preZ_AUC
# postZ_AUC
# preRZ_AUC
# postRZ_AUC

# %%
test_dico = {'bkhb':3245}
test_dico.get('bkhb')
# Out:
# 3245

# %%
type(np.float64)
# Out:
# type
