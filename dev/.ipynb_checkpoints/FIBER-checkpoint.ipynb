# %%
# %cd "../fiberphotopy"
# Out:
# C:\Users\mceau\Documents\fiberphotopy\fiberphotopy

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
import time
import random
from scipy import signal

import importlib
import fp_utils
import behavioral_data
import fiber_data
import analysis

def rel():
    importlib.reload(behavioral_data)
    importlib.reload(fiber_data)
    importlib.reload(analysis)
    importlib.reload(fp_utils)

# %%
AS21R = analysis.MultiSession('../../DATA/AS21R/')
# Out:
# Importing folder rat_10_SA_1...
# Importing ../../DATA/AS21R//rat_10_SA_1/bsa02032022c20_01.dat...
# Importing of ../../DATA/AS21R//rat_10_SA_1/bsa02032022c20_01.dat finished in 0.0389862060546875 seconds
# Analyzing peaks...
# C:\Users\mceau\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\mceau\Anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Importing of ../../DATA/AS21R//rat_10_SA_1/AS21RSA1Rat1002032022_0.csv finished in 1.7818145751953125 seconds
#
# Importing folder rat_10_SA_2...
# Importing ../../DATA/AS21R//rat_10_SA_2/bsa08032022c20_02.dat...
# Importing of ../../DATA/AS21R//rat_10_SA_2/bsa08032022c20_02.dat finished in 0.044974327087402344 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_10_SA_2/AS21RSA2Rat1008032022_0.csv finished in 1.0623784065246582 seconds
#
# Importing folder rat_11_SA_1...
# Importing ../../DATA/AS21R//rat_11_SA_1/bsa03032022c20_01.dat...
# Importing of ../../DATA/AS21R//rat_11_SA_1/bsa03032022c20_01.dat finished in 0.0419764518737793 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_11_SA_1/AS21RSA1Rat1103032022_0.csv finished in 1.7849421501159668 seconds
#
# Importing folder rat_11_SA_2...
# Importing ../../DATA/AS21R//rat_11_SA_2/bsa09032022c20_02.dat...
# Importing of ../../DATA/AS21R//rat_11_SA_2/bsa09032022c20_02.dat finished in 0.06797003746032715 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_11_SA_2/AS21RSA2Rat1109032022_0.csv finished in 1.184295892715454 seconds
#
# Importing folder rat_11_SA_3...
# Importing ../../DATA/AS21R//rat_11_SA_3/bsa11032022c20_01.dat...
# Importing of ../../DATA/AS21R//rat_11_SA_3/bsa11032022c20_01.dat finished in 0.051969051361083984 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_11_SA_3/AS21RSA3Rat1111032022_0.csv finished in 1.7907195091247559 seconds
#
# Importing folder rat_11_SA_4...
# Importing ../../DATA/AS21R//rat_11_SA_4/bsarec1_15032022c20_01.dat...
# Importing of ../../DATA/AS21R//rat_11_SA_4/bsarec1_15032022c20_01.dat finished in 0.052969932556152344 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_11_SA_4/AS21RSA4Rat1115032022_0.csv finished in 1.7328975200653076 seconds
#
# Importing folder rat_11_SA_5...
# Importing ../../DATA/AS21R//rat_11_SA_5/bsa17032022c20_01.dat...
# Importing of ../../DATA/AS21R//rat_11_SA_5/bsa17032022c20_01.dat finished in 0.04459333419799805 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_11_SA_5/AS21RSA5Rat1117032022_0.csv finished in 1.7488477230072021 seconds
#
# Importing folder rat_11_SA_6...
# Importing ../../DATA/AS21R//rat_11_SA_6/bsa22032022c20_01.dat...
# Importing of ../../DATA/AS21R//rat_11_SA_6/bsa22032022c20_01.dat finished in 0.06723761558532715 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_11_SA_6/AS21RSA6Rat1122032022_0.csv finished in 1.7492313385009766 seconds
#
# Importing folder rat_11_SA_7...
# Importing ../../DATA/AS21R//rat_11_SA_7/bsa24032022c20_01.dat...
# Importing of ../../DATA/AS21R//rat_11_SA_7/bsa24032022c20_01.dat finished in 0.08295035362243652 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat
022c20_01.dat...
# Importing of ../../DATA/AS21R//rat_3_SA_3/bsa21032022c20_01.dat finished in 0.050113677978515625 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_3_SA_3/AS21RSA3Rat321032022_0.csv finished in 1.7539591789245605 seconds
#
# Importing folder rat_5_SA_1...
# Importing ../../DATA/AS21R//rat_5_SA_1/bsa02032022c20_02.dat...
# Importing of ../../DATA/AS21R//rat_5_SA_1/bsa02032022c20_02.dat finished in 0.051970481872558594 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_5_SA_1/AS21RSA1Rat502032022_0.csv finished in 1.8177845478057861 seconds
#
# Importing folder rat_5_SA_2...
# Importing ../../DATA/AS21R//rat_5_SA_2/bsa10032022c20_01.dat...
# Importing of ../../DATA/AS21R//rat_5_SA_2/bsa10032022c20_01.dat finished in 0.04599142074584961 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_5_SA_2/AS21RSA2Rat510032022_0.csv finished in 1.8956468105316162 seconds
#
# Importing folder rat_5_SA_3...
# Importing ../../DATA/AS21R//rat_5_SA_3/bsa11032022c20_02.dat...
# Importing of ../../DATA/AS21R//rat_5_SA_3/bsa11032022c20_02.dat finished in 0.05741095542907715 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_5_SA_3/AS21RSA3Rat511032022_0.csv finished in 1.3945205211639404 seconds
#
# Importing folder rat_5_SA_4...
# Importing ../../DATA/AS21R//rat_5_SA_4/bsa15032022c20_01.dat...
# Importing of ../../DATA/AS21R//rat_5_SA_4/bsa15032022c20_01.dat finished in 0.04497385025024414 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_5_SA_4/AS21RSA4Rat515032022_0.csv finished in 1.7609784603118896 seconds
#
# Importing folder rat_5_SA_5...
# Importing ../../DATA/AS21R//rat_5_SA_5/bsarec121032022c20_01.dat...
# Importing of ../../DATA/AS21R//rat_5_SA_5/bsarec121032022c20_01.dat finished in 0.043981075286865234 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_5_SA_5/AS21RSA5Rat521032022_0.csv finished in 1.8029310703277588 seconds
#
# Importing folder rat_5_SA_6...
# Importing ../../DATA/AS21R//rat_5_SA_6/bsa23032022c20_01.dat...
# Importing of ../../DATA/AS21R//rat_5_SA_6/bsa23032022c20_01.dat finished in 0.04700660705566406 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_5_SA_6/AS21RSA6Rat523032022_0.csv finished in 1.7709999084472656 seconds
#
# Importing folder rat_5_SA_7...
# Importing ../../DATA/AS21R//rat_5_SA_7/bsa28032022c20_01.dat...
# Importing of ../../DATA/AS21R//rat_5_SA_7/bsa28032022c20_01.dat finished in 0.04797244071960449 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_5_SA_7/AS21RSAxRat528032022_0.csv finished in 1.7773501873016357 seconds
#
# Importing folder rat_8_SA_1...
# Importing ../../DATA/AS21R//rat_8_SA_1/bsa03032022c20_02.dat...
# Importing of ../../DATA/AS21R//rat_8_SA_1/bsa03032022c20_02.dat finished in 0.04297471046447754 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_8_SA_1/AS21RSA1Rat803032022recording1.csv finished in 0.35779786109924316 seconds
#
# Importing folder rat_8_SA_2...
# Importing ../../DATA/AS21R//rat_8_SA_2/bsa04032022c20_02.dat...
# Importing of ../../DATA/AS21R//rat_8_SA_2/bsa04032022c20_02.dat finished in 0.05097055435180664 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_8_SA_2/AS21RSA2Rat804032022_0.csv finished in 1.8164005279541016 seconds
#
# Importing folder rat_8_SA_3...
# Importing ../../DATA/AS21R//rat_8_SA_3/bsa09032022c20_01.dat...
# Importing of ../../DATA/AS21R//rat_8_SA_3/bsa09032022c20_01.dat finished in 0.0519256591796875 seconds
# Analyzing peaks...
# Importing of ../../DATA/AS21R//rat_8_SA_3/AS21RSA3Rat809032022_0.csv finished in 1.762953281402588 seconds
#
# Importing folder rat_8_SA_4...
# Importing ../../DATA/AS21R//rat_8_SA_4/bsarec1_16032022c20_01.dat...
# Importing of ../../DATA/AS21R//rat
# ../../DATA/AS21R//rat_8_SA_1/AS21RSA1Rat803032022recording1.csv ../../DATA/AS21R//rat_8_SA_1/bsa03032022c20_02.dat
# No fiber recording at this timestamp:
# 5700.002
# ../../DATA/AS21R//rat_8_SA_1/AS21RSA1Rat803032022recording1.csv ../../DATA/AS21R//rat_8_SA_1/bsa03032022c20_02.dat

# %%
analysis.plot('zscores')

# %%
analysis.elements
# Out:
# {'HLED_OFF': [True, 'Drug Period', '#069AF3'],
#  'HLED_ON': [True, 'No Drug Period', 'gold'],
#  'TTL1_ON': [True, 'Fiber Photometry Recordings', 'g'],
#  'np1': [True, 'Active Nosepokes', 'r'],
#  'np2': [True, 'Inactive Nosepokes', 'b'],
#  'inj1': [True, 'Injections', 'k'],
#  'LED1_ON': [True, 'Conditioned Stimulus', 'goldenrod'],
#  'LED1_OFF': [False, 'LED1_OFF', ['darkgray', 'darkgrey']],
#  'LED2_OFF': [False, 'LED2_OFF', 'slategrey'],
#  'LED2_ON': [True, ' Drug Light On', 'slategrey'],
#  'DARK': [False, 'DARK', 'k'],
#  'TO_DARK': [False, 'TO_DARK', 'olivedrab'],
#  'NOTO_DARK': [False, 'NOTO_DARK', 'black'],
#  'TIMEOUT': [True, 'Time outs', 'k'],
#  'switch_d_nd': [False, 'Switch from D to ND', 'r'],
#  'switch_to_nd': [False, 'Switch from TO to ND', 'r'],
#  'switch_nd_d': [False, 'Switch from ND to D', 'b']}

# %%
analysis.plot('signal')

# %%
def plot_things(pre,post):
    n = len(pre)
    menMeans   = (pre.mean(),post.mean())
    menStd     = (pre.std()/np.sqrt(n),post.std()/np.sqrt(n))
    ind  = np.arange(2)    # the x locations for the groups
    width= 0.7
    labels = ('A', 'B')

    # Pull the formatting out here
    bar_kwargs = {'width':width,'color':'y','linewidth':2,'zorder':5}
    err_kwargs = {'zorder':0,'fmt':'none','linewidth':2,'ecolor':'k'}  #for matplotlib >= v1.4 use 'fmt':'none' instead

    fig, ax = plt.subplots()
    ax.p1 = plt.bar(ind, menMeans, **bar_kwargs)
    ax.errs = plt.errorbar(ind, menMeans, yerr=menStd, **err_kwargs)
    
    df = pd.DataFrame({'mean':menMeans,'standard dev':(pre.std(),post.std()),'SEM':menStd},index=['pre','post'])
    return df

# %%
plot_things(np.array(analysis.preAVG_Z),np.array(analysis.postAVG_Z))
# Out:
#               mean  standard dev           SEM
# pre   8.985493e-18  4.034875e-17  5.490769e-18
# post  8.111148e-01  9.485028e-01  1.290749e-01

# %%
plot_things(np.array(analysis.preAUC),np.array(analysis.postAUC))
# Out:
#           mean  standard dev       SEM
# pre  -0.017867      0.037589  0.005115
# post  0.048101      0.061566  0.008378

# %%
columns = ['preF','preA','postF','postA','NDNP']
di = {k:[np.nan,np.nan,np.nan,np.nan] for k in analysis.rat_sessions.keys()}
for k,v in analysis.rat_sessions.items():
    T = v.behavior.timestamps('switch_dto_nd',interval='TTL1_ON')
    preF,preA,postF,postA = [],[],[],[]
    for t in T:
        try:
            pre  = v.fiber.peakFA(t-10,t)
            post = v.fiber.peakFA(t,t+10)
            preF.append(pre['frequency'])
            preA.append(pre['mean dF/F'])
            postF.append(post['frequency'])
            postA.append(post['mean dF/F'])
        except:
            print(f"didn't work for {k} at {t}")
    di[k][0] = np.mean(preF)
    di[k][1] = np.mean(preA)
    di[k][2] = np.mean(postF)
    di[k][3] = np.mean(postA)
    di[k][4]
df = pd.DataFrame.from_dict(di, orient='index',columns=columns)
df.dropna(inplace=True)
df
# Out:
# didn't work for rat_8_SA_1 at 2400.0
# didn't work for rat_8_SA_1 at 5700.002
# C:\Users\mceau\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\mceau\Anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                  preF      preA     postF     postA
# rat_10_SA_1  2.300000  0.014061  1.850000  0.019818
# rat_10_SA_2  2.800000  0.013692  2.700000  0.024144
# rat_11_SA_1  1.700000  0.020796  2.300000  0.017347
# rat_11_SA_2  1.500000  0.017900  2.300000  0.018346
# rat_11_SA_3  2.200000  0.015637  2.700000  0.017584
# rat_11_SA_4  1.500000  0.026897  1.800000  0.021984
# rat_11_SA_5  2.250000  0.015337  2.500000  0.016737
# rat_11_SA_6  2.150000  0.017665  2.500000  0.018973
# rat_11_SA_8  2.800000  0.013393  2.100000  0.019301
# rat_12_SA_1  1.400000  0.006979  0.800000  0.046215
# rat_12_SA_2  2.133333  0.013188  2.833333  0.036352
# rat_12_SA_3  1.500000  0.012175  2.600000  0.032289
# rat_12_SA_5  1.650000  0.023576  1.150000  0.052478
# rat_12_SA_6  1.950000  0.011680  2.300000  0.044249
# rat_12_SA_7  2.100000  0.023505  1.900000  0.049294
# rat_3_SA_1   2.350000  0.014831  1.600000  0.022466
# rat_3_SA_2   2.350000  0.016313  1.900000  0.025082
# rat_3_SA_3   2.000000  0.019580  1.900000  0.027289
# rat_5_SA_1   2.100000  0.022279  1.950000  0.023368
# rat_5_SA_2   2.850000  0.012583  2.100000  0.020398
# rat_5_SA_3   2.200000  0.021282  3.300000  0.020366
# rat_5_SA_4   1.500000  0.024737  2.100000  0.023121
# rat_5_SA_5   2.600000  0.012311  2.200000  0.021292
# rat_5_SA_6   2.450000  0.016219  2.500000  0.019716
# rat_5_SA_7   2.800000  0.009196  2.550000  0.020139
# rat_8_SA_2   1.800000  0.020882  2.000000  0.018687
# rat_8_SA_3   2.100000  0.018827  2.550000  0.020264
# rat_8_SA_4   2.400000  0.014032  1.850000  0.024032
# rat_8_SA_5   1.850000  0.022233  2.250000  0.028637

# %%
plot_things(df['preF'].values,df['postF'].values)
# Out:
#           mean  standard dev       SEM
# pre   2.113218      0.422576  0.078470
# post  2.175287      0.492387  0.091434

# %%
plot_things(df['preA'].values,df['postA'].values)
# Out:
#           mean  standard dev       SEM
# pre   0.016958      0.004836  0.000898
# post  0.025861      0.009931  0.001844

# %%
len(analysis.postAUC)
# Out:
# 54

# %%
len(analysis.preAUC)
# Out:
# 54
